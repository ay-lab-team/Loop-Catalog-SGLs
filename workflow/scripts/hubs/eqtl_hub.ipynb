# %%
import os 
import json
import glob
import gzip
import pandas as pd 

outdir = 'results/main/hubs/eqtl_hub/'
link_path = 'https://informaticsdata.liai.org/BioAdHoc/Groups/vd-ay/jreyna/projects/dchallenge/results/main/hubs/eqtl_hub/'
os.makedirs(outdir, exist_ok=True)

os.chdir('/mnt/BioHome/jreyna/jreyna/projects/dchallenge/')

# %% [markdown]
# ## Get all WashU Files

# %% [raw]
# # setting template names
# eqtl_tpl = 'results/main/eqtl/*/ge/*_ge_*.all.dist.fdr.onekg.anno.vcf.gz'

# %% [raw]
# eqtl_data = []
# for eqtl in glob.glob(eqtl_tpl.format(eqtl_source='*')):
#
#     run_info = eqtl.split('/')
#     eqtl_source = run_info[3]
#     ge_source = run_info[-1].split('.')[0].split('ge')[1].replace('_', '', 1)
#     eqtl_data.append([eqtl_source, ge_source, eqtl])
#
# eqtl_df = pd.DataFrame(eqtl_data)
# eqtl_df.columns = ['eqtl_source', 'ge_source', 'file']

# %% [raw]
# eqtl_df

# %% [markdown]
# ## Making the Hub

# %%
def create_washu_longrange_dict(name, file):
    d = {'type': 'longrange',
         'showOnHubLoad': True,
         'name': name,
         'filename': file,
         'options': {'displayMode': 'arc'}}
    return(d)

def create_washu_bed_dict(name, file):
    d = {'type': 'bed',
         'showOnHubLoad': True,
         'name': name,
         'filename': file}
    return(d)

def create_washu_vcf_dict(name, file):
    d = {'type': 'vcf',
         'showOnHubLoad': True,
         'name': name,
         'filename': file,
         'options': {'ensemblStyle': True, 'height': 100, 'displayMode': 'auto'}}
    return(d)

def create_washu_geneAnnotation_dict(name, file):
    d = {'type': 'refbed',
         'showOnHubLoad': True,
         'name': name,
         'filename': file}
    return(d)

# %%
def create_remote_washu_vcf_dict(name, url):
    d = {'type': 'vcf',
         'showOnHubLoad': True,
         'name': name,
         'url': url,
         'options': {'ensemblStyle': True, 'height': 100, 'displayMode': 'auto'}}
    return(d)

# %%
def create_remote_washu_vcf_dict(name, url):
    d = {'type': 'vcf',
         'showOnHubLoad': True,
         'name': name,
         'url': url,
         'options': {'ensemblStyle': True, 'height': 100, 'displayMode': 'auto'}}
    return(d)

# %% [markdown]
# ## Making the Hub

# %% [raw]
# json_files = []
#
# for i, sr in eqtl_df.iterrows():
#
#     print(sr.file)
#
#     basename = os.path.basename(sr.file)
#
#     old_path = sr.file
#     old_index_path = sr.file + '.tbi'
#
#     new_basename = '{}.{}'.format(sr.gwas_source, basename)
#     new_path = os.path.join(outdir, new_basename)
#     new_index_path = new_path + '.tbi'
#
#     print('new_path:', new_path)
#     print()
#
#     if os.path.exists(old_path) and os.path.exists(old_index_path):
#         if not os.path.exists(new_path) and not os.path.exists(new_index_path):
#
#             os.link(old_path, new_path)
#             os.link(old_index_path, new_index_path)
#
#         # add the file to the json hub config
#         authorship = gwas_meta.loc[sr.gwas_source, 'authorship']
#         name = 'eQTL SNPs (Sigs Only) - {}'.format(authorship)
#         url = os.path.join(link_path, new_basename)
#         d = create_remote_washu_vcf_dict(name, url)
#         json_files.append(d)

# %% [markdown]
# ## Making the BedRef based-Hub

# %%
# setting template names
eqtl_tpl = 'results/main/eqtl/*/ge/*_ge_*.all.dist.fdr.track.bed.gz'

# %%
glob.glob(eqtl_tpl.format(eqtl_source='*'))
# Out:
# ['results/main/eqtl/GTEx/ge/GTEx_ge_LCL.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/GTEx/ge/GTEx_ge_blood.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/GTEx/ge/GTEx_ge_pancreas.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/Lepik_2017/ge/Lepik_2017_ge_blood.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/Quach_2016/ge/Quach_2016_ge_monocyte_Pam3CSK4.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/Quach_2016/ge/Quach_2016_ge_monocyte_naive.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/Quach_2016/ge/Quach_2016_ge_monocyte_R848.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/Quach_2016/ge/Quach_2016_ge_monocyte_IAV.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/Quach_2016/ge/Quach_2016_ge_monocyte_LPS.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/BLUEPRINT/ge/BLUEPRINT_ge_neutrophil.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/BLUEPRINT/ge/BLUEPRINT_ge_monocyte.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/BLUEPRINT/ge/BLUEPRINT_ge_T-cell.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/Schmiedel_2018/ge/Schmiedel_2018_ge_Tfh_memory.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/Schmiedel_2018/ge/Schmiedel_2018_ge_CD8_T-cell_anti-CD3-CD28.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/Schmiedel_2018/ge/Schmiedel_2018_ge_monocyte_naive.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/Schmiedel_2018/ge/Schmiedel_2018_ge_NK-cell_naive.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/Schmiedel_2018/ge/Schmiedel_2018_ge_Th1_memory.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/Schmiedel_2018/ge/Schmiedel_2018_ge_Th17_memory.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/Schmiedel_2018/ge/Schmiedel_2018_ge_CD4_T-cell_anti-CD3-CD28.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/Schmiedel_2018/ge/Schmiedel_2018_ge_CD4_T-cell_naive.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/Schmiedel_2018/ge/Schmiedel_2018_ge_Th1-17_memory.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/Schmiedel_2018/ge/Schmiedel_2018_ge_B-cell_naive.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/Schmiedel_2018/ge/Schmiedel_2018_ge_Th2_memory.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/Schmiedel_2018/ge/Schmiedel_2018_ge_Treg_naive.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/Schmiedel_2018/ge/Schmiedel_2018_ge_monocyte_CD16_naive.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/Schmiedel_2018/ge/Schmiedel_2018_ge_CD8_T-cell_naive.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/Schmiedel_2018/ge/Schmiedel_2018_ge_Treg_memory.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/GENCORD/ge/GENCORD_ge_T-cell.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/GENCORD/ge/GENCORD_ge_LCL.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/van_de_Bunt_2015/ge/van_de_Bunt_2015_ge_pancreatic_islet.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_CD16p_Mono.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Int_Mono.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Naive_B.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_mDC.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Plasmablast.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_SM_B.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Neu.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_LDG.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Th17.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Fr_III_T.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_EM_CD8.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_DN_B.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Mem_CD8.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Fr_I_nTreg.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_NC_Mono.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_CL_Mono.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Fr_II_eTreg.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_CM_CD8.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Naive_CD4.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_TEMRA_CD8.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_USM_B.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Mem_CD4.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Tfh.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Th1.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_NK.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_pDC.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Naive_CD8.all.dist.fdr.track.bed.gz',
#  'results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Th2.all.dist.fdr.track.bed.gz']

# %%
eqtl_data = []
for eqtl in glob.glob(eqtl_tpl.format(eqtl_source='*')):
        
    run_info = eqtl.split('/')
    eqtl_source = run_info[3]  
    ge_source = run_info[-1].split('.')[0].split('ge')[1].replace('_', '', 1)
    eqtl_data.append([eqtl_source, ge_source, eqtl])
    
eqtl_df = pd.DataFrame(eqtl_data)
eqtl_df.columns = ['eqtl_source', 'ge_source', 'file']

# %%
eqtl_df
# Out:
#          eqtl_source                 ge_source  \
# 0               GTEx                       LCL
# 1               GTEx                     blood
# 2               GTEx                  pancreas
# 3         Lepik_2017                     blood
# 4         Quach_2016         monocyte_Pam3CSK4
# 5         Quach_2016            monocyte_naive
# 6         Quach_2016             monocyte_R848
# 7         Quach_2016              monocyte_IAV
# 8         Quach_2016              monocyte_LPS
# 9          BLUEPRINT                neutrophil
# 10         BLUEPRINT                  monocyte
# 11         BLUEPRINT                    T-cell
# 12    Schmiedel_2018                Tfh_memory
# 13    Schmiedel_2018  CD8_T-cell_anti-CD3-CD28
# 14    Schmiedel_2018            monocyte_naive
# 15    Schmiedel_2018             NK-cell_naive
# 16    Schmiedel_2018                Th1_memory
# 17    Schmiedel_2018               Th17_memory
# 18    Schmiedel_2018  CD4_T-cell_anti-CD3-CD28
# 19    Schmiedel_2018          CD4_T-cell_naive
# 20    Schmiedel_2018             Th1-17_memory
# 21    Schmiedel_2018              B-cell_naive
# 22    Schmiedel_2018                Th2_memory
# 23    Schmiedel_2018                Treg_naive
# 24    Schmiedel_2018       monocyte_CD16_naive
# 25    Schmiedel_2018          CD8_T-cell_naive
# 26    Schmiedel_2018               Treg_memory
# 27           GENCORD                    T-cell
# 28           GENCORD                       LCL
# 29  van_de_Bunt_2015          pancreatic_islet
# 30         ImmuNexUT                CD16p_Mono
# 31         ImmuNexUT                  Int_Mono
# 32         ImmuNexUT                   Naive_B
# 33         ImmuNexUT                       mDC
# 34         ImmuNexUT               Plasmablast
# 35         ImmuNexUT                      SM_B
# 36         ImmuNexUT                       Neu
# 37         ImmuNexUT                       LDG
# 38         ImmuNexUT                      Th17
# 39         ImmuNexUT                  Fr_III_T
# 40         ImmuNexUT                    EM_CD8
# 41         ImmuNexUT                      DN_B
# 42         ImmuNexUT                   Mem_CD8
# 43         ImmuNexUT                Fr_I_nTreg
# 44         ImmuNexUT                   NC_Mono
# 45         ImmuNexUT                   CL_Mono
# 46         ImmuNexUT               Fr_II_eTreg
# 47         ImmuNexUT                    CM_CD8
# 48         ImmuNexUT                 Naive_CD4
# 49         ImmuNexUT                 TEMRA_CD8
# 50         ImmuNexUT                     USM_B
# 51         ImmuNexUT                   Mem_CD4
# 52         ImmuNexUT                       Tfh
# 53         ImmuNexUT                       Th1
# 54         ImmuNexUT                        NK
# 55         ImmuNexUT                       pDC
# 56         ImmuNexUT                 Naive_CD8
# 57         ImmuNexUT                       Th2
#
#                                                  file
# 0   results/main/eqtl/GTEx/ge/GTEx_ge_LCL.all.dist...
# 1   results/main/eqtl/GTEx/ge/GTEx_ge_blood.all.di...
# 2   results/main/eqtl/GTEx/ge/GTEx_ge_pancreas.all...
# 3   results/main/eqtl/Lepik_2017/ge/Lepik_2017_ge_...
# 4   results/main/eqtl/Quach_2016/ge/Quach_2016_ge_...
# 5   results/main/eqtl/Quach_2016/ge/Quach_2016_ge_...
# 6   results/main/eqtl/Quach_2016/ge/Quach_2016_ge_...
# 7   results/main/eqtl/Quach_2016/ge/Quach_2016_ge_...
# 8   results/main/eqtl/Quach_2016/ge/Quach_2016_ge_...
# 9   results/main/eqtl/BLUEPRINT/ge/BLUEPRINT_ge_ne...
# 10  results/main/eqtl/BLUEPRINT/ge/BLUEPRINT_ge_mo...
# 11  results/main/eqtl/BLUEPRINT/ge/BLUEPRINT_ge_T-...
# 12  results/main/eqtl/Schmiedel_2018/ge/Schmiedel_...
# 13  results/main/eqtl/Schmiedel_2018/ge/Schmiedel_...
# 14  results/main/eqtl/Schmiedel_2018/ge/Schmiedel_...
# 15  results/main/eqtl/Schmiedel_2018/ge/Schmiedel_...
# 16  results/main/eqtl/Schmiedel_2018/ge/Schmiedel_...
# 17  results/main/eqtl/Schmiedel_2018/ge/Schmiedel_...
# 18  results/main/eqtl/Schmiedel_2018/ge/Schmiedel_...
# 19  results/main/eqtl/Schmiedel_2018/ge/Schmiedel_...
# 20  results/main/eqtl/Schmiedel_2018/ge/Schmiedel_...
# 21  results/main/eqtl/Schmiedel_2018/ge/Schmiedel_...
# 22  results/main/eqtl/Schmiedel_2018/ge/Schmiedel_...
# 23  results/main/eqtl/Schmiedel_2018/ge/Schmiedel_...
# 24  results/main/eqtl/Schmiedel_2018/ge/Schmiedel_...
# 25  results/main/eqtl/Schmiedel_2018/ge/Schmiedel_...
# 26  results/main/eqtl/Schmiedel_2018/ge/Schmiedel_...
# 27  results/main/eqtl/GENCORD/ge/GENCORD_ge_T-cell...
# 28  results/main/eqtl/GENCORD/ge/GENCORD_ge_LCL.al...
# 29  results/main/eqtl/van_de_Bunt_2015/ge/van_de_B...
# 30  results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_CD...
# 31  results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_In...
# 32  results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Na...
# 33  results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_mD...
# 34  results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Pl...
# 35  results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_SM...
# 36  results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Ne...
# 37  results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_LD...
# 38  results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Th...
# 39  results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Fr...
# 40  results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_EM...
# 41  results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_DN...
# 42  results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Me...
# 43  results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Fr...
# 44  results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_NC...
# 45  results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_CL...
# 46  results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Fr...
# 47  results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_CM...
# 48  results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Na...
# 49  results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_TE...
# 50  results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_US...
# 51  results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Me...
# 52  results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Tf...
# 53  results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Th...
# 54  results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_NK...
# 55  results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_pD...
# 56  results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Na...
# 57  results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Th...

# %%
def create_remote_washu_refbed_dict(name, url):
    d = {'type': 'refbed',
         'showOnHubLoad': True,
         'name': name,
         'url': url,
         'options': {'ensemblStyle': True,
                     'height': 100,
                     'displayMode': 'auto',
                     'categoryColors': {
                        'Sig': 'rgb(255,0,0)',
                        'Not Sig.': 'rgb(0,0,255)'}}}
    return(d)

# %%
json_files = []

for i, sr in eqtl_df.iterrows():
    
    print(sr.file)
    
    basename = os.path.basename(sr.file)
    
    old_path = sr.file
    old_index_path = sr.file + '.tbi'
    
    new_basename = '{}.{}'.format(sr.eqtl_source, basename)
    new_path = os.path.join(outdir, new_basename)
    new_index_path = new_path + '.tbi'
    
    print('new_path:', new_path)
    print()

    if os.path.exists(old_path) and os.path.exists(old_index_path):
        if not os.path.exists(new_path) and not os.path.exists(new_index_path):
                
            os.link(old_path, new_path)
            os.link(old_index_path, new_index_path)

        # add the file to the json hub config
        name = 'eQTL SNPs - {} {}'.format(sr.eqtl_source, sr.ge_source)
        url = os.path.join(link_path, new_basename)
        d = create_remote_washu_refbed_dict(name, url)
        json_files.append(d)
# Out:
# results/main/eqtl/GTEx/ge/GTEx_ge_LCL.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/GTEx.GTEx_ge_LCL.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/GTEx/ge/GTEx_ge_blood.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/GTEx.GTEx_ge_blood.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/GTEx/ge/GTEx_ge_pancreas.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/GTEx.GTEx_ge_pancreas.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/Lepik_2017/ge/Lepik_2017_ge_blood.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/Lepik_2017.Lepik_2017_ge_blood.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/Quach_2016/ge/Quach_2016_ge_monocyte_Pam3CSK4.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/Quach_2016.Quach_2016_ge_monocyte_Pam3CSK4.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/Quach_2016/ge/Quach_2016_ge_monocyte_naive.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/Quach_2016.Quach_2016_ge_monocyte_naive.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/Quach_2016/ge/Quach_2016_ge_monocyte_R848.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/Quach_2016.Quach_2016_ge_monocyte_R848.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/Quach_2016/ge/Quach_2016_ge_monocyte_IAV.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/Quach_2016.Quach_2016_ge_monocyte_IAV.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/Quach_2016/ge/Quach_2016_ge_monocyte_LPS.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/Quach_2016.Quach_2016_ge_monocyte_LPS.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/BLUEPRINT/ge/BLUEPRINT_ge_neutrophil.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/BLUEPRINT.BLUEPRINT_ge_neutrophil.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/BLUEPRINT/ge/BLUEPRINT_ge_monocyte.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/BLUEPRINT.BLUEPRINT_ge_monocyte.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/BLUEPRINT/ge/BLUEPRINT_ge_T-cell.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/BLUEPRINT.BLUEPRINT_ge_T-cell.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/Schmiedel_2018/ge/Schmiedel_2018_ge_Tfh_memory.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/Schmiedel_2018.Schmiedel_2018_ge_Tfh_memory.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/Schmiedel_2018/ge/Schmiedel_2018_ge_CD8_T-cell_anti-CD3-CD28.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/Schmiedel_2018.Schmiedel_2018_ge_CD8_T-cell_anti-CD3-CD28.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/Schmiedel_2018/ge/Schmiedel_2018_ge_monocyte_naive.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/Schmiedel_2018.Schmiedel_2018_ge_monocyte_naive.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/Schmiedel_2018/ge/Schmiedel_2018_ge_NK-cell_naive.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/Schmiedel_2018.Schmiedel_2018_ge_NK-cell_naive.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/Schmiedel_2018/ge/Schmiedel_2018_ge_Th1_memory.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/Schmiedel_2018.Schmiedel_2018_ge_Th1_memory.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/Schmiedel_2018/ge/Schmiedel_2018_ge_Th17_memory.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/Schmiedel_2018.Schmiedel_2018_ge_Th17_memory.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/Schmiedel_2018/ge/Schmiedel_2018_ge_CD4_T-cell_anti-CD3-CD28.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/Schmiedel_2018.Schmiedel_2018_ge_CD4_T-cell_anti-CD3-CD28.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/Schmiedel_2018/ge/Schmiedel_2018_ge_CD4_T-cell_naive.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/Schmiedel_2018.Schmiedel_2018_ge_CD4_T-cell_naive.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/Schmiedel_2018/ge/Schmiedel_2018_ge_Th1-17_memory.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/Schmiedel_2018.Schmiedel_2018_ge_Th1-17_memory.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/Schmiedel_2018/ge/Schmiedel_2018_ge_B-cell_naive.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/Schmiedel_2018.Schmiedel_2018_ge_B-cell_naive.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/Schmiedel_2018/ge/Schmiedel_2018_ge_Th2_memory.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/Schmiedel_2018.Schmiedel_2018_ge_Th2_memory.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/Schmiedel_2018/ge/Schmiedel_2018_ge_Treg_naive.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/Schmiedel_2018.Schmiedel_2018_ge_Treg_naive.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/Schmiedel_2018/ge/Schmiedel_2018_ge_monocyte_CD16_naive.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/Schmiedel_2018.Schmiedel_2018_ge_monocyte_CD16_naive.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/Schmiedel_2018/ge/Schmiedel_2018_ge_CD8_T-cell_naive.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/Schmiedel_2018.Schmiedel_2018_ge_CD8_T-cell_naive.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/Schmiedel_2018/ge/Schmiedel_2018_ge_Treg_memory.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/Schmiedel_2018.Schmiedel_2018_ge_Treg_memory.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/GENCORD/ge/GENCORD_ge_T-cell.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/GENCORD.GENCORD_ge_T-cell.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/GENCORD/ge/GENCORD_ge_LCL.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/GENCORD.GENCORD_ge_LCL.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/van_de_Bunt_2015/ge/van_de_Bunt_2015_ge_pancreatic_islet.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/van_de_Bunt_2015.van_de_Bunt_2015_ge_pancreatic_islet.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_CD16p_Mono.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/ImmuNexUT.ImmuNexUT_ge_CD16p_Mono.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Int_Mono.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/ImmuNexUT.ImmuNexUT_ge_Int_Mono.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Naive_B.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/ImmuNexUT.ImmuNexUT_ge_Naive_B.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_mDC.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/ImmuNexUT.ImmuNexUT_ge_mDC.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Plasmablast.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/ImmuNexUT.ImmuNexUT_ge_Plasmablast.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_SM_B.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/ImmuNexUT.ImmuNexUT_ge_SM_B.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Neu.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/ImmuNexUT.ImmuNexUT_ge_Neu.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_LDG.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/ImmuNexUT.ImmuNexUT_ge_LDG.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Th17.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/ImmuNexUT.ImmuNexUT_ge_Th17.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Fr_III_T.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/ImmuNexUT.ImmuNexUT_ge_Fr_III_T.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_EM_CD8.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/ImmuNexUT.ImmuNexUT_ge_EM_CD8.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_DN_B.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/ImmuNexUT.ImmuNexUT_ge_DN_B.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Mem_CD8.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/ImmuNexUT.ImmuNexUT_ge_Mem_CD8.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Fr_I_nTreg.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/ImmuNexUT.ImmuNexUT_ge_Fr_I_nTreg.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_NC_Mono.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/ImmuNexUT.ImmuNexUT_ge_NC_Mono.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_CL_Mono.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/ImmuNexUT.ImmuNexUT_ge_CL_Mono.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Fr_II_eTreg.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/ImmuNexUT.ImmuNexUT_ge_Fr_II_eTreg.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_CM_CD8.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/ImmuNexUT.ImmuNexUT_ge_CM_CD8.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Naive_CD4.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/ImmuNexUT.ImmuNexUT_ge_Naive_CD4.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_TEMRA_CD8.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/ImmuNexUT.ImmuNexUT_ge_TEMRA_CD8.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_USM_B.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/ImmuNexUT.ImmuNexUT_ge_USM_B.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Mem_CD4.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/ImmuNexUT.ImmuNexUT_ge_Mem_CD4.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Tfh.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/ImmuNexUT.ImmuNexUT_ge_Tfh.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Th1.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/ImmuNexUT.ImmuNexUT_ge_Th1.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_NK.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/ImmuNexUT.ImmuNexUT_ge_NK.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_pDC.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/ImmuNexUT.ImmuNexUT_ge_pDC.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Naive_CD8.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/ImmuNexUT.ImmuNexUT_ge_Naive_CD8.all.dist.fdr.track.bed.gz
#
# results/main/eqtl/ImmuNexUT/ge/ImmuNexUT_ge_Th2.all.dist.fdr.track.bed.gz
# new_path: results/main/hubs/eqtl_hub/ImmuNexUT.ImmuNexUT_ge_Th2.all.dist.fdr.track.bed.gz

# %%
hub_path = os.path.join(outdir, 'hub.config.json')
with open(hub_path, 'w') as fw:
    print(json.dumps(json_files, indent='\t'), file=fw)
