# %% [markdown]
# # Processing Calderon 2019

# %% [markdown]
# Calderon et al., 2019 published the following paper [Landscape of stimulation-responsive chromatin across diverse human immune cells](https://www.nature.com/articles/s41588-019-0505-9). This paper was really interesting because the author looked at resting versus stimulated immunes cells via ATACseq and RNAseq and intersecting these datasets with GWAS for a variety of immune diseases. This notebook is incomplete but my goal was to understand what GWAS variants were prioritized in this study.

# %%
import os
import pandas as pd
import myvariant

# %%
os.chdir('/mnt/BioHome/jreyna/jreyna/projects/dchallenge/')

# %%
fn = 'results/main/calderon_2019/41588_2019_505_MOESM8_ESM.tsv'
supp = pd.read_table(fn)

# %%
def to_hgvs_id(sr):
    s = '{}:g.{}{}>{}'.format(sr.chr, sr.pos, sr.refAllele, sr.altAllele)
    return(s)

supp['hgvs_id'] = supp.apply(to_hgvs_id, axis=1)

# %%
t1d = supp.loc[supp.Phenotype == 'Type 1 diabetes']
#t1d = t1d.loc[t1d.stim == False]

# %%
# generate a dictionary of hgvs id to rsid
mv = myvariant.MyVariantInfo()
query = mv.getvariants(t1d.hgvs_id.unique(), fields=['dbsnp.rsid'])

hgvs_to_rsid = {}
for rec in query:
    
    if 'dbsnp' in rec:
        hgvs_to_rsid[rec['query']] = rec['dbsnp']['rsid']
    else:
        hgvs_to_rsid[rec['query']] = 'Not Found'
# Out:
# querying 1-4...done.

# %%
t1d['rsid'] = t1d['hgvs_id'].replace(hgvs_to_rsid)
# Out:
# /tmp/ipykernel_89676/455408412.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t1d['rsid'] = t1d['hgvs_id'].replace(hgvs_to_rsid)

# %%
t1d
# Out:
#               Phenotype    chr        pos  dbSNP134_id   gwas_pvalue  \
# 54      Type 1 diabetes   chr1  206939904      3024505  2.100000e-11
# 56      Type 1 diabetes   chr1  206939904      3024505  2.100000e-11
# 58      Type 1 diabetes   chr1  206939904      3024505  4.700000e-10
# 69      Type 1 diabetes   chr1  206939904      3024505  2.100000e-11
# 75      Type 1 diabetes   chr1  206939904      3024505  4.700000e-10
# ...                 ...    ...        ...          ...           ...
# 726882  Type 1 diabetes  chr10    6114660     41295061  3.900000e-24
# 726883  Type 1 diabetes  chr10    6114660     41295061  3.900000e-24
# 726884  Type 1 diabetes  chr10    6114660     41295061  3.900000e-24
# 726885  Type 1 diabetes  chr10    6114660     41295061  3.900000e-24
# 726886  Type 1 diabetes  chr10    6114660     41295061  3.900000e-24
#
#             PMID  TotalDiscoverySamples  donor                      cell  \
# 54      19430480                  16559   1002               Myeloid_DCs
# 56      19430480                  16559   1002                 Monocytes
# 58      21829393                  12501   1002               Myeloid_DCs
# 69      19430480                  16559   1002               Myeloid_DCs
# 75      21829393                  12501   1002               Myeloid_DCs
# ...          ...                    ...    ...                       ...
# 726882  18978792                   8207   1004  Effector_memory_CD8pos_T
# 726883  18978792                   8207   1004  Effector_memory_CD8pos_T
# 726884  18978792                   8207   1004           Th17_precursors
# 726885  18978792                   8207   1004           Th17_precursors
# 726886  18978792                   8207   1004               Naive_Teffs
#
#          stim  ... logFC_atac adj.P.Val_atac  nearby_de_gene_id  contrast_rna  \
# 54      False  ...  -1.800962   4.183291e-04                NaN           NaN
# 56       True  ...  -1.800962   4.183291e-04                NaN           NaN
# 58      False  ...  -1.800962   4.183291e-04                NaN           NaN
# 69      False  ...  -1.800962   4.183291e-04                NaN           NaN
# 75      False  ...  -1.918953   5.971444e-05                NaN           NaN
# ...       ...  ...        ...            ...                ...           ...
# 726882   True  ...   2.556422   1.016120e-07                NaN           NaN
# 726883   True  ...   2.556422   1.016120e-07                NaN           NaN
# 726884   True  ...   3.359023   1.384793e-09                NaN           NaN
# 726885   True  ...   3.359023   1.384793e-09                NaN           NaN
# 726886   True  ...   1.734125   5.731227e-04                NaN           NaN
#
#         logFC_rna adj.P.Val_rna                                 tested_TF  \
# 54            NaN           NaN         ENSG00000008196_LINE4_TFAP2B_D_N1
# 56            NaN           NaN         ENSG00000008196_LINE4_TFAP2B_D_N1
# 58            NaN           NaN         ENSG00000008196_LINE4_TFAP2B_D_N1
# 69            NaN           NaN         ENSG00000008196_LINE4_TFAP2B_D_N1
# 75            NaN           NaN         ENSG00000008196_LINE4_TFAP2B_D_N1
# ...           ...           ...                                       ...
# 726882        NaN           NaN  ENSG00000230336_LINE17148_CR8477943_I_N5
# 726883        NaN           NaN  ENSG00000230336_LINE17148_CR8477943_I_N5
# 726884        NaN           NaN  ENSG00000230336_LINE17148_CR8477943_I_N5
# 726885        NaN           NaN  ENSG00000230336_LINE17148_CR8477943_I_N5
# 726886        NaN           NaN  ENSG00000230336_LINE17148_CR8477943_I_N5
#
#         ref_minus_alt_match              hgvs_id        rsid
# 54                 3.825278  chr1:g.206939904G>A   rs3024505
# 56                 3.825278  chr1:g.206939904G>A   rs3024505
# 58                 3.825278  chr1:g.206939904G>A   rs3024505
# 69                 3.825278  chr1:g.206939904G>A   rs3024505
# 75                 3.825278  chr1:g.206939904G>A   rs3024505
# ...                     ...                  ...         ...
# 726882            -4.025442   chr10:g.6114660C>A  rs41295061
# 726883            -4.025442   chr10:g.6114660C>A  rs41295061
# 726884            -4.025442   chr10:g.6114660C>A  rs41295061
# 726885            -4.025442   chr10:g.6114660C>A  rs41295061
# 726886            -4.025442   chr10:g.6114660C>A  rs41295061
#
# [42632 rows x 27 columns]

# %%
t1d.rsid.unique()
# Out:
# array(['rs3024505', 'rs61839660', 'rs998592', 'rs41295061'], dtype=object)

# %%
t1d.drop_duplicates(subset=['chr', 'pos'])
# Out:
#              Phenotype    chr        pos  dbSNP134_id   gwas_pvalue      PMID  \
# 54     Type 1 diabetes   chr1  206939904      3024505  2.100000e-11  19430480
# 7748   Type 1 diabetes  chr10    6094697     61839660  5.100000e-09  22293688
# 12690  Type 1 diabetes  chr16   11199678       998592  4.960000e-09  17632545
# 27254  Type 1 diabetes  chr10    6114660     41295061  3.900000e-24  18978792
#
#        TotalDiscoverySamples  donor                      cell   stim  ...  \
# 54                     16559   1002               Myeloid_DCs  False  ...
# 7748                   16179   1004  Effector_memory_CD8pos_T   True  ...
# 12690                   3105   1003  Effector_memory_CD8pos_T   True  ...
# 27254                   8207   1004  Effector_memory_CD8pos_T   True  ...
#
#       logFC_atac adj.P.Val_atac  nearby_de_gene_id  contrast_rna  logFC_rna  \
# 54     -1.800962   4.183291e-04                NaN           NaN        NaN
# 7748   -1.774487   2.767275e-05                NaN           NaN        NaN
# 12690   1.615495   5.408296e-05                NaN           NaN        NaN
# 27254   2.556422   1.016120e-07                NaN           NaN        NaN
#
#       adj.P.Val_rna                           tested_TF  ref_minus_alt_match  \
# 54              NaN   ENSG00000008196_LINE4_TFAP2B_D_N1             3.825278
# 7748            NaN  ENSG00000116017_LINE45_ARID3A_D_N1            -4.021372
# 12690           NaN  ENSG00000072310_LINE94_SREBF1_D_N3            -4.183004
# 27254           NaN   ENSG00000164330_LINE255_EBF1_D_N1             2.932422
#
#                    hgvs_id        rsid
# 54     chr1:g.206939904G>A   rs3024505
# 7748    chr10:g.6094697C>T  rs61839660
# 12690  chr16:g.11199678C>T    rs998592
# 27254   chr10:g.6114660C>A  rs41295061
#
# [4 rows x 27 columns]

# %%
for x in supp.Phenotype.unique():
    print(x)
# Out:
# Transmission distortion
# Maternal transmission distortion
# Serum creatinine
# Height
# Breast cancer (male breast cancer)
# Irritible bowel syndrome
# Primary biliary cirrhosis
# Crohn's disease
# Type 1 diabetes
# Selective immunoglobulin A deficiency (IgAD)
# Ulcerative colitis
# Inflammatory bowel disease
# Total cholesterol
# Plasma alpha-linolenic acid levels
# Plasma docosapentaenoic acid levels
# Plasma eicosapentaenoic acid levels
# Classical Hodgkin's lymphoma
# Helicobacter pylori seroprevalence
# Efavirenz pharmacokinetics (log-transformed trough efavirenz concentration)
# Coronary artery disease (CAD) with age of onset <=50
# Coronary artery disease (CAD)
# Aortic root size
# Serum urate
# Uric acid
# Gout
# LDL cholesterol
# Glycan Peak 1
# Biantennary nongalactosylated glycans
# Biantennary nongalactosylated glycans in women
# Desialylated Glycan Peak 1 in women
# Glycan Peak 1 in women
# Desialylated Glycan Peak 1
# Height (adults)
# Height (adult females)
# Paternal transmission distortion
# Fasting blood glucose
# Triglycerides
# Body mass index (BMI)
# Desialylated Glycan Peak 1 in men
# Hair morphology
# Interleukin-6 (IL-6) levels
# Late onset Alzheimer's disease
# Peripartum cardiomyopathy
# Lumbar spine bone mineral density (BMD)
# Femoral neck areal bone mineral density (BMD)
# Lumbar spine bone mineral density  (BMD) (male)
# Lumbar spine bone mineral density  (BMD) (female)
# Lumbar spine bone mineral density (BMD) (females)
# Femoral neck bone mineral density (BMD)
# Lumbar spine areal bone mineral density (BMD)
# Femoral neck bone mineral density (BMD) (females)
# Circulating galectin-3 levels
# Plasma protein-C levels
# Alopecia areata
# Beta-thalassemia/Hemoglobin E disease (severity)
# Fetal hemoglobin level (the proportion of F-cells in sickle-cell disease)
# Fetal hemoglobin
# Adult fetal hemoblogbin levels (HbF) by F cell levels
# Fetal hemoglobin (HbF)
# Beta-thalassemia/Hemoglobin E disease (absolute fetal hemoglobin (Hb), g/dL)
# Pam3CSK4-induced interleukin-6 (IL-6)
# Mean corpuscular volume (MCV)
# Mean corpuscular hemoglobin concentration (MCHC)
# Factor XIII A subunit
# Central corneal thickness
# HDL cholesterol
# Triglycerides (males)
# Triglycerides (females)
# Myopia
# Soluble transferrin receptor
# Neuroblastoma (brain cancer)
# Esophageal squamous cell carcinoma (Esophageal cancer)
# Serum matrix metalloproteinase (MMP1)
# Serum magnesium
# Mean corpuscular hemoglobin (MCH)
# Red blood cell count (RBC)
# Generalized vitiligo
# Nicotine dependence (smoking), cigarettes per day
# Lung cancer
# Rheumatoid arthritis
# Waist hip ratio
# Hemoglobin (Hb)
# Primary sclerosing cholangitis
# Metabolites in glutathione and glycine biosynthesis pathways
# College completion
# Celiac disease
# Testicular germ cell tumor (testicular cancer)
# Platelet count
# Birth weight
# Fibrotic idiopathic interstitial pneumonias (pulmonary fibrosis)
# Lung function, ratio of forced expiratory volume in 1 second (FEV1) to forced vital capacity (FVC) (FEV1/FVC)
# ETV6-RUNX1-rearranged childhood acute lymphoblastic leukemia (ALL)
# Childhood acute lymphoblastic leukemia
# Childhood acute lymphoblastic leukemia (ALL)
# Primary biliary cirrhosis (anti-mitochondrial antibody positive)
# Primary biliary cirrhosis in females
# Triglycerides, ln
# Spine bone mineral density (BMD)
# Hip bone mineral density (BMD)
# Spine bone mineral density (BMD) (females)
# APOA1 (apolipoprotein AI)
# Asthma
# Asthma, childhood, later and unknown onset, and severe and industrial asthma
# Asthma, childhood and later onset
# Asthma, childhood, later and unknown onset, and severe asthma
# Asthma, childhood onset
# Type 2 diabetes
# 1-hour glucose tolerance test in nondiabetic subjects
# Glycosylated hemoglobin in nondiabetic subjects
# Monocyte count
# Total serum IgE
# IgE in plasma
# von Willebrand factor (vWF)
# Thyroid cancer
# Glaucoma (normal pressure glaucoma)
# Height tails (upper and lower 5th percentiles)
# Gene expression
# Multiple sclerosis
# Psoriatic arthritis
# Psoriasis
# Grave's disease
# Persistent TRAb autoantibody positive Grave's disease
# Hematocrit (Hct)
# Skin freckles
# Freckles+burns vs. no freckles+tans
# Pancreatic cancer
# Infantile hypertrophic pyloric stenosis
# RNASET2 gene expression in CD4+ T cells
# Myocardial infarction (MI)
# Myocardial infarction (MI) (male)
# Hypertension
# Plasma carcinoembryonic antigen (CEA) levels
# Triglycerides, mmol/l
# Triglycerides by NMR lipoprotein fraction
# VLDL cholesterol small lipoprotein fraction concentration in fasting sample
# VLDL cholesterol small lipoprotein fraction concentration
# VLDL cholesterol medium lipoprotein fraction concentration
# VLDL cholesterol large lipoprotein fraction concentration
# VLDL cholesterol total lipoprotein fraction concentration
# HDL cholesterol change with statins
# Triglycerides lipoprotein fraction
# VLDL cholesterol total lipoprotein fraction concentration in fasting sample
# Serum triglycerides levels (males)
# Serum calcium
# ATP1B3 expression in Lymphocytes tissue
# Cortical bone mineral density (BMD)
# Age-related macular degeneration (Stage 5 ARMD)
# Advanced age-related macular degeneration
# Advanced age-related macular degeneration (geographic atrophy)
# Age-related macular degeneration
# Advanced age-related macular degeneration (choroidal neovascularization) vs. no AMD
# Kawasaki disease
