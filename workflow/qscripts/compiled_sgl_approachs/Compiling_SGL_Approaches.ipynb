# %%
import os 
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
import subprocess
import glob
import pybedtools as pbt 
pbt.set_tempdir('/mnt/hpcscratch/jreyna/')

pbt.set_bedtools_path('/mnt/BioApps/bedtools/bin/')
import numpy as np

os.chdir('/mnt/BioHome/jreyna/jreyna/projects/dchallenge/')

genome_sizes = 'results/refs/hg19/hg19.chrom.sizes'

# make the directory to save our data
outdir = 'results/main/compiled_sgl_approaches/'
os.makedirs(outdir, exist_ok=True)

# %% [markdown]
# ## Loading SGLs from different sources

# %%
coloc_fn = 'results/main/coloc/sgl_intersect/coloc_ld_sgls.tsv'

# %%
pieqtl_fn = 'results/main/pieqtls/sgl_intersect/pieqtls_sgls.tsv'

# %%
finemap_fn = 'results/main/finemapping/sgl_intersect/finemap_sgls.tsv'

# %%
coloc = pd.read_table(coloc_fn)
coloc['sgl_type'] = 'coloc'

pieqtl = pd.read_table(pieqtl_fn)
pieqtl['sgl_type'] = 'pieqtl'

finemap = pd.read_table(finemap_fn)
finemap['sgl_type'] = 'finemap'

# Adding chr to the chromosome columns 
finemap['chrA_loop'] = 'chr' + finemap['chrA_loop'].astype(str)
finemap['chrB_loop'] = 'chr' + finemap['chrB_loop'].astype(str)

# %% [markdown]
# ## Loading Gene Data

# %%
print('# Load the gene data')

res = 5000

genes_fn = 'results/refs/gencode/v30/gencode.v30.annotation.bed'

# load the gencode coords
cols = ['chrom', 'start', 'end', 'strand', 'type', 'gene_id', 'gname']
gencode = pd.read_table(genes_fn, header=None, names=cols)

# extract just the genes
genes_df = gencode.loc[gencode['type'].isin(['gene'])]
genes_df = genes_df.loc[~genes_df.duplicated(subset='gene_id'), :]
genes_df.loc[:, 'chrom'] = genes_df['chrom'].astype(str)
genes_df = genes_df.iloc[:, [0,1,2,6,5,3]]

print(genes_df.head())

print('There are {} genes in this GTF-derived file.'.format(genes_df.shape[0]))
# Out:
# # Load the gene data
#    chrom  start    end        gname          gene_id strand
# 0   chr1  11869  14409      DDX11L1  ENSG00000223972      +
# 12  chr1  14404  29570       WASH7P  ENSG00000227232      -
# 25  chr1  17369  17436    MIR6859-1  ENSG00000278267      -
# 28  chr1  29554  31109  MIR1302-2HG  ENSG00000243485      +
# 36  chr1  30366  30503    MIR1302-2  ENSG00000284332      +
# There are 58825 genes in this GTF-derived file.

# %%
coloc
# Out:
#     chr_snp  start_snp    end_snp chr_gene  start_gene   end_gene  coloc.id  \
# 0     chr18   12830537   12830538    chr18    11857553   11857554         3
# 1     chr18   12838765   12838766    chr18    11857553   11857554         4
# 2     chr18   12866435   12866436    chr18    11857553   11857554         5
# 3     chr18   12884342   12884343    chr18    11857553   11857554         6
# 4     chr18   12856907   12856908    chr18    11857553   11857554        15
# ..      ...        ...        ...      ...         ...        ...       ...
# 438    chr4  123067807  123067808     chr4   122884711  122884712        78
# 439    chr4  123087956  123087957     chr4   122884711  122884712        49
# 440    chr4  123116994  123116995     chr4   122884711  122884712        76
# 441    chr4  123116861  123116862     chr4   122884711  122884712        77
# 442    chr4  123076894  123076895     chr4   122884711  122884712        87
#
#       chrA     startA       endA   chrB     startB       endB  loop.id    chr  \
# 439        1  0.880380      0           0         0  8.717059e-07
# 440        1  0.880380      0           0         0  8.717059e-07
# 441        1  0.880380      0           0         0  8.717059e-07
# 442        1  0.880380      0           0         0  8.717059e-07
#
#      exp_cc_Bias        p_Bias   dbinom_Bias  P-Value_Bias  Q-Value_Bias  \
# 0       4.878204  4.563685e-08  9.383704e-09  1.187546e-08      0.000003
# 1       4.878204  4.563685e-08  9.383704e-09  1.187546e-08      0.000003
# 2       4.878204  4.563685e-08  9.383704e-09  1.187546e-08      0.000003
# 3       4.878204  4.563685e-08  9.383704e-09  1.187546e-08      0.000003
# 4       4.878204  4.563685e-08  9.383704e-09  1.187546e-08      0.000003
# ..           ...           ...           ...           ...           ...
# 438     2.125524  1.476179e-08  5.260317e-08  6.118760e-08      0.000007
# 439     2.125524  1.476179e-08  5.260317e-08  6.118760e-08      0.000007
# 440     2.125524  1.476179e-08  5.260317e-08  6.118760e-08      0.000007
# 441     2.125524  1.476179e-08  5.260317e-08  6.118760e-08      0.000007
# 442     2.125524  1.476179e-08  5.260317e-08  6.118760e-08      0.000007
#
#              celltype sgl_type
# 0      monocyte_naive    coloc
# 1      monocyte_naive    coloc
# 2      monocyte_naive    coloc
# 3      monocyte_naive    coloc
# 4      monocyte_naive    coloc
# ..                ...      ...
# 438  CD4_T-cell_naive    coloc
# 439  CD4_T-cell_naive    coloc
# 440  CD4_T-cell_naive    coloc
# 441  CD4_T-cell_naive    coloc
# 442  CD4_T-cell_naive    coloc
#
# [443 rows x 71 columns]

# %% [markdown]
# ## Intersecting PC-HiC Data

# %% [markdown]
# #### Coloc Approach

# %%
# creating a dictionary which matches 
# hichip and pc-hic data
hichip_pchic_matches = {'monocytes': 'monocyte_naive',
                        'naive-b': 'B-cell_naive',
                        'total-b': 'B-cell_naive',
                        'gms_merged': 'B-cell_naive', 
                        'naive-cd4': 'CD4_T-cell_naive', 
                        'total-cd4': 'CD4_T-cell_naive', 
                        'non-activated-total-cd4': 'CD4_T-cell_naive',
                        'naive-cd8': 'CD8_T-cell_naive',
                        'total-cd8': 'CD8_T-cell_naive'}

# %%
# getting a list of pc_hic files 
pc_hics = glob.glob('results/main/pc_hic/2016_javierre/processing/*.bedpe')
pc_hics += glob.glob('results/main/pc_hic/2019_jung/processing/*.bedpe')

# adding a merge id for post fixing
coloc['mid'] = range(coloc.shape[0])

# renaming loop columns
coloc.rename(columns={'chrA': 'chrA_loop', 'startA': 'startA_loop', 'endA': 'endA_loop',
                      'chrB': 'chrB_loop', 'startB': 'startB_loop', 'endB': 'endB_loop',
                      'celltype': 'cline_loop'}, inplace=True)

# initializing the merge list and column names
pchic_merge_data = []
pchic_cols = ['chrA', 'startA', 'endA', 'chrB', 'startB', 'endB', 'score', 'pchic_cline']
hichip_bedpe_cols = ['chrA_loop', 'startA_loop', 'endA_loop',
                    'chrB_loop', 'startB_loop', 'endB_loop', 'mid']
for fn in pc_hics:
    pchic_cline = os.path.basename(fn).split('.')[0]
    
    if pchic_cline in hichip_pchic_matches: 
        
        # getting hichip data for the current cell line
        hichip_cline = hichip_pchic_matches[pchic_cline]
        hichip_cline_df = coloc.loc[coloc.cline_loop == hichip_cline, hichip_bedpe_cols]
        
        # loading pc-hic data for the current cell line
        pchic_cline_df = pd.read_table(fn, names=pchic_cols)
        #pchic_cline_df.chrA = pchic_cline_df.chrA.str.replace('chr', '')
        #pchic_cline_df.chrB = pchic_cline_df.chrB.str.replace('chr', '')
        
        # intersecting hichip and pc-hic bedpes
        hichip_cline_pbt = pbt.BedTool.from_dataframe(hichip_cline_df)
        pchic_cline_pbt = pbt.BedTool.from_dataframe(pchic_cline_df)
        
        
        both_loops = hichip_cline_pbt.pairtopair(pchic_cline_pbt)        
        both_loops = both_loops.to_dataframe(disable_auto_names=True, header=None).iloc[:, 0:15]
        
        if both_loops.shape[0] > 0: 
            pchic_merge_data.append(both_loops)
            print('overlap found: {}'.format(fn))
        else:
            print('overlap not found: {}'.format(fn))
# Out:
# overlap found: results/main/pc_hic/2016_javierre/processing/non-activated-total-cd4.bedpe
# overlap not found: results/main/pc_hic/2016_javierre/processing/monocytes.bedpe
# overlap not found: results/main/pc_hic/2016_javierre/processing/naive-b.bedpe
# overlap found: results/main/pc_hic/2016_javierre/processing/total-cd8.bedpe
# overlap found: results/main/pc_hic/2016_javierre/processing/total-cd4.bedpe
# overlap not found: results/main/pc_hic/2016_javierre/processing/total-b.bedpe
# overlap found: results/main/pc_hic/2016_javierre/processing/naive-cd4.bedpe
# overlap found: results/main/pc_hic/2016_javierre/processing/naive-cd8.bedpe
# overlap not found: results/main/pc_hic/2019_jung/processing/gms_merged.bedpe

# %%
pchic_merge_df = pd.concat(pchic_merge_data, axis=0)
pchic_merge_df.columns = ['hichip_chrA', 'hichip_startA', 'hichip_endA',
                    'hichip_chrB', 'hichip_startB', 'hichip_endB', 'hichip_mid', 
                    'pchic_chrA', 'pchic_startA', 'pchic_endA',
                    'pchic_chrB', 'pchic_startB', 'pchic_endB', 'pchic_score', 'pchic_cline']
pchic_merge_df = pchic_merge_df.sort_values('pchic_score', ascending=False)
pchic_merge_df = pchic_merge_df.drop_duplicates(subset=['hichip_mid'], keep='first')

# creating a table of HiChIP ID versus PC-HiC cell versus score (entries) 
pchic_merge_clean = pchic_merge_df[['hichip_mid', 'pchic_score', 'pchic_cline']]
pchic_merge_clean = pchic_merge_clean.pivot(index='hichip_mid', columns='pchic_cline', values='pchic_score')
pchic_merge_clean.columns = 'pchic.' + pchic_merge_clean.columns

# merging and cleaning the merged dataset 
coloc = coloc.merge(pchic_merge_clean, left_on='mid', right_on='hichip_mid')
coloc.drop('mid', axis=1, inplace=True)

# no overlap with gms_merged so manually adding 
coloc['pchic.monocytes'] = np.nan
coloc['pchic.naive-b'] = np.nan
coloc['pchic.total-b'] = np.nan
coloc['pchic.gms_merged'] = np.nan
coloc['pchic.total-cd8'] = np.nan

# %%
# adding column to specify PC-HiC Support
pchic_support = []
for i, sr in coloc.iterrows():
    
    pchic_supp = 0 
    if sr.cline_loop == 'CD4_T-cell_naive':
        if sr['pchic.naive-cd4'] >= 5 or sr['pchic.total-cd4'] >= 5 or sr['pchic.non-activated-total-cd4'] > 5:
            pchic_supp = 1 
            
    elif sr.cline_loop == 'CD8_T-cell_naive':
        if sr['pchic.naive-cd8'] >= 5 or sr['pchic.total-cd8'] >= 5:
            pchic_supp = 1 
            
    elif sr.cline_loop == 'monocyte_naive':
        if sr['pchic.monocytes'] >= 5:
            pchic_supp = 1             
            
    elif sr.cline_loop == 'B-cell_naive':
        if sr['pchic.naive-b'] >= 5 or sr['pchic.total-b'] >= 5 or sr['pchic.gms_merged'] >= 5:
            pchic_supp = 1        
    
    pchic_support.append(pchic_supp)
        
coloc['pchic_support'] = pchic_support

# %%
coloc = coloc.merge(genes_df[['gene_id', 'gname']], left_on='geneName', right_on='gene_id')

# %%
coloc
# Out:
#    chr_snp  start_snp    end_snp chr_gene  start_gene   end_gene  coloc.id  \
# 0     chr6   91002493   91002494     chr6    90320442   90320443         3
# 1     chr6   90986319   90986320     chr6    90320442   90320443         4
# 2     chr6   90995979   90995980     chr6    90320442   90320443         5
# 3     chr6   90996768   90996769     chr6    90320442   90320443         5
# 4     chr6   90996768   90996769     chr6    90320442   90320443         5
# 5     chr6   90968948   90968949     chr6    90320442   90320443         6
# 6     chr6   90985158   90985159     chr6    90320442   90320443         6
# 7     chr6   90985158   90985159     chr6    90320442   90320443         6
# 8     chr6   91002493   91002494     chr6    90320442   90320443        15
# 9     chr6   91002493   91002494     chr6    90320442   90320443        15
# 10    chr6   90999601   90999602     chr6    90320442   90320443         1
# 11    chr6   90999601   90999602     chr6    90320442   90320443         1
# 12    chr6   90958230   90958231     chr6    90320442   90320443         2
# 13    chr6   90958230   90958231     chr6    90320442   90320443         2
# 14    chr6   90991130   90991131     chr6    90320442   90320443         7
# 15    chr6   90998321   90998322     chr6    90320442   90320443         8
# 16    chr6   90990049   90990050     chr6    90320442   90320443         9
# 17    chr6   90996348   90996349     chr6    90320442   90320443         9
# 18    chr6   90996348   90996349     chr6    90320442   90320443         9
# 19    chr6   90975998   90975999     chr6    90320442   90320443        10
# 20    chr6   90957802   90957803     chr6    90320442   90320443        10
# 21    chr6   90957802   90957803     chr6    90320442   90320443        10
# 22    chr6   90960328   90960329     chr6    90320442   90320443        11
# 23    chr6   90973002   90973003     chr6    90320442   90320443        11
# 24    chr6   90973002   90973003     chr6    90320442   90320443        11
# 25    chr6   90989124   90989125     chr6    90320442   90320443        12
# 26    chr6   90971098   90971099     chr6    90320442   90320443        12
# 27    chr6   90971098   90971099     chr6    90320442   90320443        12
# 28    chr6   90993566   90993567     chr6    90320442   90320443        13
# 29    chr6   90982932   90982933     chr6    90320442   90320443        16
# 30    chr6   90982932   90982933     chr6    90320442   90320443        16
# 31   chr10    6106551    6106552    chr10     6202692    6202693         3
# 32   chr10    6106637    6106638    chr10     6202692    6202693         4
# 33   chr10    6118126    6118127    chr10     6202692    6202693         4
# 34   chr10    6108339    6108340    chr10     6202692    6202693         0
# 35   chr10    6114292    6114293    chr10     6202692    6202693         0
# 36   chr10    6106265    6106266    chr10     6202692    6202693         2
# 37   chr10    6120050    6120051    chr10     6202692    6202693         2
# 38   chr10    6098823    6098824    chr10     6025977    6025978         3
# 14   4296430  rs10814917  0.891468   chr6   90345000   90350000   chr6
# 15   4296430  rs10814917  0.956543   chr6   90345000   90350000   chr6
# 16   4296430  rs10814917  0.942558   chr6   90345000   90350000   chr6
# 17   4296430  rs10814917  0.942558   chr6   90345000   90350000   chr6
# 18   4296430  rs10814917  0.942558   chr6   90345000   90350000   chr6
# 19   4296430  rs10814917  0.896632   chr6   90345000   90350000   chr6
# ...
# 2                             NaN              NaN              NaN
# 3                             NaN              NaN              NaN
# 4                             NaN              NaN              NaN
# 5                             NaN              NaN              NaN
# 6                             NaN              NaN              NaN
# 7                             NaN              NaN              NaN
# 8                             NaN              NaN              NaN
# 9                             NaN              NaN              NaN
# 10                            NaN              NaN              NaN
# 11                            NaN              NaN              NaN
# 12                            NaN              NaN              NaN
# 13                            NaN              NaN              NaN
# 14                            NaN              NaN              NaN
# 15                            NaN              NaN              NaN
# 16                            NaN              NaN              NaN
# 17                            NaN              NaN              NaN
# 18                            NaN              NaN              NaN
# 19                            NaN              NaN              NaN
# 20                            NaN              NaN              NaN
# 21                            NaN              NaN              NaN
# 22                            NaN              NaN              NaN
# 23                            NaN              NaN              NaN
# 24                            NaN              NaN              NaN
# 25                            NaN              NaN              NaN
# 26                            NaN              NaN              NaN
# 27                            NaN              NaN              NaN
# 28                            NaN              NaN              NaN
# 29                            NaN              NaN              NaN
# 30                            NaN              NaN              NaN
# 31                       3.375686              NaN              NaN
# 32                       3.375686              NaN              NaN
# 33                       3.375686              NaN              NaN
# 34                       3.375686              NaN              NaN
# 35                       3.375686              NaN              NaN
# 36                       3.375686              NaN              NaN
# 37                       3.375686              NaN              NaN
# 38                            NaN              NaN              NaN
# 39                            NaN              NaN              NaN
# 40                            NaN              NaN              NaN
# 41                            NaN              NaN              NaN
# 42                            NaN              NaN              NaN
# 43                            NaN              NaN              NaN
# 44                            NaN              NaN              NaN
# 45                            NaN              NaN              NaN
# 46                            NaN              NaN              NaN
# 47                            NaN              NaN              NaN
# 48                            NaN              NaN              NaN
# 49                            NaN              NaN              NaN
# 50                            NaN              NaN              NaN
# 51                            NaN         8.515936              NaN
# 52                            NaN              NaN              NaN
# 53                            NaN              NaN              NaN
# 54                            NaN              NaN              NaN
# 55                            NaN              NaN              NaN
# 56                            NaN              NaN              NaN
# 57                            NaN              NaN              NaN
# 58                            NaN              NaN              NaN
# 59                            NaN              NaN              NaN
# 60                            NaN              NaN              NaN
# 61                            NaN              NaN              NaN
# 62                            NaN              NaN              NaN
# 63                            NaN              NaN              NaN
# 64                            NaN              NaN              NaN
# 65                            NaN              NaN              NaN
# 66                            NaN              NaN              NaN
# 67                            NaN              NaN              NaN
# 68                            NaN              NaN              NaN
# 69                            NaN              NaN              NaN
# 70                            NaN              NaN              NaN
# 71                            NaN              NaN              NaN
# 72                            NaN              NaN              NaN
# 73                            NaN              NaN              NaN
# 74                            NaN              NaN              NaN
# 75                            NaN              NaN              NaN
# 76                            NaN              NaN              NaN
# 77                            NaN              NaN              NaN
# 78                            NaN              NaN              NaN
# 79                            NaN              NaN              NaN
# 80                            NaN              NaN              NaN
# 81                            NaN              NaN              NaN
# 82                            NaN              NaN              NaN
# 83                            NaN              NaN              NaN
# 84                            NaN              NaN              NaN
# 85                            NaN              NaN              NaN
#
#     pchic.naive-b  pchic.total-b  pchic.gms_merged  pchic.total-cd8  \
# 0             NaN            NaN               NaN              NaN
# 1             NaN            NaN               NaN              NaN
# 2             NaN            NaN               NaN              NaN
# 3             NaN            NaN               NaN              NaN
# 4             NaN            NaN               NaN              NaN
# 5             NaN            NaN               NaN              NaN
# 6             NaN            NaN               NaN              NaN
# 7             NaN            NaN               NaN              NaN
# 8             NaN            NaN               NaN              NaN
# 9             NaN            NaN               NaN              NaN
# 10            NaN            NaN               NaN              NaN
# 11            NaN            NaN               NaN              NaN
# 12            NaN            NaN               NaN              NaN
# 13            NaN            NaN               NaN              NaN
# 14            NaN            NaN               NaN              NaN
# 15            NaN            NaN               NaN              NaN
# 16            NaN            NaN               NaN              NaN
# 17            NaN            NaN               NaN              NaN
# 18            NaN            NaN               NaN              NaN
# 19            NaN            NaN               NaN              NaN
# 20            NaN            NaN               NaN              NaN
# 21            NaN            NaN               NaN              NaN
# 22            NaN            NaN               NaN              NaN
# 23            NaN            NaN               NaN              NaN
# 24            NaN            NaN               NaN              NaN
# 25            NaN            NaN               NaN              NaN
# 26            NaN            NaN               NaN              NaN
# 27            NaN            NaN               NaN              NaN
# 28            NaN            NaN               NaN              NaN
# 29            NaN            NaN               NaN              NaN
# 30            NaN            NaN               NaN              NaN
# 31            NaN            NaN               NaN              NaN
# 32            NaN            NaN               NaN              NaN
# 33            NaN            NaN               NaN              NaN
# 34            NaN            NaN               NaN              NaN
# 35            NaN            NaN               NaN              NaN
# 36            NaN            NaN               NaN              NaN
# 37            NaN            NaN               NaN              NaN
# 38            NaN            NaN               NaN              NaN
# 39            NaN            NaN               NaN              NaN
# 40            NaN            NaN               NaN              NaN
# 41            NaN            NaN               NaN              NaN
# 42            NaN            NaN               NaN              NaN
# 43            NaN            NaN               NaN              NaN
# 44            NaN            NaN               NaN              NaN
# 45            NaN            NaN               NaN              NaN
# 46            NaN            NaN               NaN              NaN
# 47            NaN            NaN               NaN              NaN
# 48            NaN            NaN               NaN              NaN
# 49            NaN            NaN               NaN              NaN
# 50            NaN            NaN               NaN              NaN
# 51            NaN            NaN               NaN              NaN
# 52            NaN            NaN               NaN              NaN
# 53            NaN            NaN               NaN              NaN
# 54            NaN            NaN               NaN              NaN
# 55            NaN            NaN               NaN              NaN
# 56            NaN            NaN               NaN              NaN
# 57            NaN            NaN               NaN              NaN
# 58            NaN            NaN               NaN              NaN
# 59            NaN            NaN               NaN              NaN
# 60            NaN            NaN               NaN              NaN
# 61            NaN            NaN               NaN              NaN
# 62            NaN            NaN               NaN              NaN
# 63            NaN            NaN               NaN              NaN
# 64            NaN            NaN               NaN              NaN
# 65            NaN            NaN               NaN              NaN
# 52              0  ENSG00000206052   DOK6
# 53              0  ENSG00000206052   DOK6
# 54              0  ENSG00000206052   DOK6
# 55              0  ENSG00000206052   DOK6
# 56              0  ENSG00000206052   DOK6
# 57              0  ENSG00000206052   DOK6
# 58              0  ENSG00000206052   DOK6
# 59              0  ENSG00000206052   DOK6
# 60              0  ENSG00000206052   DOK6
# 61              0  ENSG00000206052   DOK6
# 62              0  ENSG00000206052   DOK6
# 63              0  ENSG00000206052   DOK6
# 64              0  ENSG00000206052   DOK6
# 65              0  ENSG00000206052   DOK6
# 66              0  ENSG00000206052   DOK6
# 67              0  ENSG00000206052   DOK6
# 68              0  ENSG00000206052   DOK6
# 69              0  ENSG00000206052   DOK6
# 70              0  ENSG00000206052   DOK6
# 71              0  ENSG00000206052   DOK6
# 72              0  ENSG00000206052   DOK6
# 73              0  ENSG00000206052   DOK6
# 74              0  ENSG00000206052   DOK6
# 75              0  ENSG00000206052   DOK6
# 76              0  ENSG00000206052   DOK6
# 77              0  ENSG00000206052   DOK6
# 78              0  ENSG00000206052   DOK6
# 79              0  ENSG00000206052   DOK6
# 80              0  ENSG00000206052   DOK6
# 81              0  ENSG00000206052   DOK6
# 82              0  ENSG00000206052   DOK6
# 83              0  ENSG00000206052   DOK6
# 84              0  ENSG00000206052   DOK6
# 85              0  ENSG00000206052   DOK6

# %%
coloc_cols = ['chrA_loop', 'startA_loop', 'endA_loop',
                'chrB_loop', 'startB_loop', 'endB_loop', 
                'pos', 'ld_rsID', 'gname', 'gene_id', 'cline_loop', 'sgl_type', 'pchic.monocytes', 
                'pchic.naive-b', 'pchic.naive-cd4', 'pchic.naive-cd8',
                'pchic.non-activated-total-cd4', 'pchic.total-b',
                'pchic.total-cd4', 'pchic.total-cd8','pchic_support', 'rs_id']

# %%
# coloc_cols = ['chrA', 'startA', 'endA',
#                 'chrB', 'startB', 'endB', 
#                 'pos', 'ld_rsID', 'gname', 'gene_id', 'cline_loop', 'sgl_type', 'pchic.monocytes', 
#                 'pchic.naive-b', 'pchic.naive-cd4', 'pchic.naive-cd8',
#                 'pchic.non-activated-total-cd4', 'pchic.total-b',
#                 'pchic.total-cd4', 'pchic.total-cd8','pchic_support', 'rs_id']

# %%
coloc_min = coloc.loc[:, coloc_cols]

# %%
coloc_min.columns = ['chrA', 'startA', 'endA',
                      'chrB', 'startB', 'endB',
                      'pos', 'rsid', 'genename', 'geneid', 
                      'cline', 'sgl_type', 'pchic.monocytes',
                      'pchic.naive-b', 'pchic.naive-cd4', 'pchic.naive-cd8',
                      'pchic.non-activated-total-cd4', 'pchic.total-b',
                      'pchic.total-cd4', 'pchic.total-cd8','pchic_support', 'lead.rs_id']

# %%
coloc_min
# Out:
#      chrA     startA       endA   chrB     startB       endB       pos  \
# 0    chr6   90345000   90350000   chr6   91005000   91010000   4293150
# 1    chr6   90345000   90350000   chr6   91005000   91010000   4296430
# 2    chr6   90345000   90350000   chr6   91005000   91010000   4283682
# 3    chr6   90345000   90350000   chr6   91005000   91010000   4283682
# 4    chr6   90345000   90350000   chr6   91005000   91010000   4283682
# 5    chr6   90345000   90350000   chr6   91005000   91010000   4284961
# 6    chr6   90345000   90350000   chr6   91005000   91010000   4284961
GLIS3  ENSG00000107249  CD4_T-cell_naive    coloc
# 47  rs10814916    GLIS3  ENSG00000107249  CD8_T-cell_naive    coloc
# 48  rs10758591    GLIS3  ENSG00000107249  CD8_T-cell_naive    coloc
# 49  rs10814914    GLIS3  ENSG00000107249  CD8_T-cell_naive    coloc
# 50  rs10814915    GLIS3  ENSG00000107249  CD8_T-cell_naive    coloc
# 51   rs7041847    GLIS3  ENSG00000107249  CD4_T-cell_naive    coloc
# 52  rs17207042     DOK6  ENSG00000206052  CD4_T-cell_naive    coloc
# 53  rs17207042     DOK6  ENSG00000206052  CD4_T-cell_naive    coloc
# 54   rs1788103     DOK6  ENSG00000206052  CD4_T-cell_naive    coloc
# 55   rs1788103     DOK6  ENSG00000206052  CD4_T-cell_naive    coloc
# 56   rs1788105     DOK6  ENSG00000206052  CD4_T-cell_naive    coloc
# 57   rs1788105     DOK6  ENSG00000206052  CD4_T-cell_naive    coloc
# 58   rs1788232     DOK6  ENSG00000206052  CD4_T-cell_naive    coloc
# 59   rs1788232     DOK6  ENSG00000206052  CD4_T-cell_naive    coloc
# 60   rs1790575     DOK6  ENSG00000206052  CD4_T-cell_naive    coloc
# 61   rs1790575     DOK6  ENSG00000206052  CD4_T-cell_naive    coloc
# 62   rs1790588     DOK6  ENSG00000206052  CD4_T-cell_naive    coloc
# 63   rs1790588     DOK6  ENSG00000206052  CD4_T-cell_naive    coloc
# 64  rs11151544     DOK6  ENSG00000206052  CD4_T-cell_naive    coloc
# 65  rs11151544     DOK6  ENSG00000206052  CD4_T-cell_naive    coloc
# 66  rs11661553     DOK6  ENSG00000206052  CD4_T-cell_naive    coloc
# 67  rs11661553     DOK6  ENSG00000206052  CD4_T-cell_naive    coloc
# 68  rs12969657     DOK6  ENSG00000206052  CD4_T-cell_naive    coloc
# 69  rs12969657     DOK6  ENSG00000206052  CD4_T-cell_naive    coloc
# 70  rs13381239     DOK6  ENSG00000206052  CD4_T-cell_naive    coloc
# 71  rs13381239     DOK6  ENSG00000206052  CD4_T-cell_naive    coloc
# 72   rs1610554     DOK6  ENSG00000206052  CD4_T-cell_naive    coloc
# 73   rs1610554     DOK6  ENSG00000206052  CD4_T-cell_naive    coloc
# 74   rs1615504     DOK6  ENSG00000206052  CD4_T-cell_naive    coloc
# 75   rs1615504     DOK6  ENSG00000206052  CD4_T-cell_naive    coloc
# 76   rs1788098     DOK6  ENSG00000206052  CD4_T-cell_naive    coloc
# 77   rs1788098     DOK6  ENSG00000206052  CD4_T-cell_naive    coloc
# 78   rs1790961     DOK6  ENSG00000206052  CD4_T-cell_naive    coloc
# 79   rs1790961     DOK6  ENSG00000206052  CD4_T-cell_naive    coloc
# 80   rs1790962     DOK6  ENSG00000206052  CD4_T-cell_naive    coloc
# 81   rs1790962     DOK6  ENSG00000206052  CD4_T-cell_naive    coloc
# 82   rs1808094     DOK6  ENSG00000206052  CD4_T-cell_naive    coloc
# 83   rs1808094     DOK6  ENSG00000206052  CD4_T-cell_naive    coloc
# 84   rs1790963     DOK6  ENSG00000206052  CD4_T-cell_naive    coloc
# 85   rs1790963     DOK6  ENSG00000206052  CD4_T-cell_naive    coloc
#
#     pchic.monocytes  pchic.naive-b  pchic.naive-cd4  pchic.naive-cd8  \
# 0               NaN            NaN         3.418659              NaN
# 1               NaN            NaN         3.418659              NaN
# 2               NaN            NaN         3.418659              NaN
# 3               NaN            NaN         3.418659              NaN
# 4               NaN            NaN         3.418659              NaN
# 5               NaN            NaN         3.418659              NaN
# 6               NaN            NaN         3.418659              NaN
# 7               NaN            NaN         3.418659              NaN
# 8               NaN            NaN         3.418659              NaN
# 9               NaN            NaN         3.418659              NaN
# 10              NaN            NaN         3.418659              NaN
# 11              NaN            NaN         3.418659              NaN
# 12              NaN            NaN         3.418659              NaN
# 13              NaN            NaN         3.418659              NaN
# 14              NaN            NaN         3.418659              NaN
# 15              NaN            NaN         3.418659              NaN
# 16              NaN            NaN         3.418659              NaN
# 17              NaN            NaN         3.418659              NaN
# 18              NaN            NaN         3.418659              NaN
# 19              NaN            NaN         3.418659              NaN
# 20              NaN            NaN         3.418659              NaN
# 21              NaN            NaN         3.418659              NaN
# 22              NaN            NaN         3.418659              NaN
# 23              NaN            NaN         3.418659              NaN
# 24              NaN            NaN         3.418659              NaN
# 25              NaN            NaN         3.418659              NaN
# 26              NaN            NaN         3.418659              NaN
# 27              NaN            NaN         3.418659              NaN
# 28              NaN            NaN         3.418659              NaN
# 29              NaN            NaN         3.418659              NaN
# 30              NaN            NaN         3.418659              NaN
# 31              NaN            NaN              NaN              NaN
# 32              NaN            NaN              NaN              NaN
# 33              NaN            NaN              NaN              NaN
# 34              NaN            NaN              NaN              NaN
# 35              NaN            NaN              NaN              NaN
# 36              NaN            NaN              NaN              NaN
# 37              NaN            NaN              NaN              NaN
# 38              NaN            NaN         6.562224              NaN
# 39              NaN            NaN         6.562224              NaN
# 40              NaN            NaN         6.562224              NaN
# 41              NaN            NaN         6.562224              NaN
# 42              NaN            NaN         6.562224              NaN
# 43              NaN            NaN         6.562224              NaN
# 44              NaN            NaN         6.562224              NaN
# 45              NaN            NaN         6.562224              NaN
# 46              NaN            NaN         6.562224              NaN
# 47              NaN            NaN              NaN         1.205284
# 48              NaN            NaN              NaN         1.205284
# 49              NaN            NaN              NaN         1.205284
# 50              NaN            NaN              NaN         1.205284
# 51              NaN            NaN              NaN              NaN
# 52              NaN            NaN         3.418659              NaN
# 53              NaN            NaN         3.418659              NaN
# 54              NaN            NaN         3.418659              NaN
# 55              NaN            NaN         3.418659              NaN
# 56              NaN            NaN         3.418659              NaN
# 57              NaN            NaN         3.418659              NaN
# 58              NaN            NaN         3.418659              NaN
# 59              NaN            NaN         3.418659              NaN
# 60              NaN            NaN         3.418659              NaN
# 61              NaN            NaN         3.418659              NaN
# 62              NaN            NaN         3.418659              NaN
# 63              NaN            NaN         3.418659              NaN
# 64              NaN            NaN         3.418659              NaN
# 65              NaN            NaN         3.418659              NaN
# 66              NaN            NaN         3.418659              NaN
# 67              NaN            NaN         3.418659              NaN
# 68              NaN            NaN         3.418659              NaN
# 69              NaN            NaN         3.418659              NaN
# 70              NaN            NaN         3.418659              NaN
# 71              NaN            NaN         3.418659              NaN
# 72              NaN            NaN         3.418659              NaN
# 73              NaN            NaN         3.418659              NaN
# 74              NaN            NaN         3.418659              NaN
# 75              NaN            NaN         3.418659              NaN
# 76              NaN            NaN         3.418659              NaN
# 77              NaN            NaN         3.418659              NaN
# 78              NaN            NaN         3.418659              NaN
# 79              NaN            NaN         3.418659              NaN
# 80              NaN            NaN         3.418659              NaN
# 81              NaN            NaN         3.418659              NaN
# 82              NaN            NaN         3.418659              NaN
# 83              NaN            NaN         3.418659              NaN
# 84              NaN            NaN         3.418659              NaN
# 85              NaN            NaN         3.418659              NaN
#
#     pchic.non-activated-total-cd4  pchic.total-b  pchic.total-cd4  \
# 0                             NaN            NaN              NaN
# 1                             NaN            NaN              NaN
# 2                             NaN            NaN              NaN
# 3                             NaN            NaN              NaN
# 4                             NaN            NaN              NaN
# 5                             NaN            NaN              NaN
# 6                             NaN            NaN              NaN
# 7                             NaN            NaN              NaN
# 8                             NaN            NaN              NaN
# 9                             NaN            NaN              NaN
# 10                            NaN            NaN              NaN
# 11                            NaN            NaN              NaN
# 12                            NaN            NaN              NaN
# 13                            NaN            NaN              NaN
# 14                            NaN            NaN              NaN
# 15                            NaN            NaN              NaN
# 16                            NaN            NaN              NaN
# 17                            NaN            NaN              NaN
# 18                            NaN            NaN              NaN
# 19                            NaN            NaN              NaN
# 20                            NaN            NaN              NaN
# 21                            NaN            NaN              NaN
# 22                            NaN            NaN              NaN
# 23                            NaN            NaN              NaN
# 24                            NaN            NaN              NaN
# 25                            NaN            NaN              NaN
# 26                            NaN            NaN              NaN
# 27                            NaN            NaN              NaN
# 28                            NaN            NaN              NaN
# 29                            NaN            NaN              NaN
# 30                            NaN            NaN              NaN
# 31                       3.375686            NaN              NaN
# 32                       3.375686            NaN              NaN
# 33                       3.375686            NaN              NaN
# 34                       3.375686            NaN              NaN
# 35                       3.375686            NaN              NaN
# 36                       3.375686            NaN              NaN
# 37                       3.375686            NaN              NaN
# 38                            NaN            NaN              NaN
# 39                            NaN            NaN              NaN
# 40                            NaN            NaN              NaN
# 41                            NaN            NaN              NaN
# 42                            NaN            NaN              NaN
# 43                            NaN            NaN              NaN
# 44                            NaN            NaN              NaN
# 45                            NaN            NaN              NaN
# 46                            NaN            NaN              NaN
# 47                            NaN            NaN              NaN
# 48                            NaN            NaN              NaN
# 49                            NaN            NaN              NaN
# 50                            NaN            NaN              NaN
# 51                            NaN            NaN         8.515936
# 52                            NaN            NaN              NaN
# 53                            NaN            NaN              NaN
# 54                            NaN            NaN              NaN
# 55                            NaN            NaN              NaN
# 56                            NaN            NaN              NaN
# 57                            NaN            NaN              NaN
# 58                            NaN            NaN              NaN
# 59                            NaN            NaN              NaN
# 60                            NaN            NaN              NaN
# 61                            NaN            NaN              NaN
# 62                            NaN            NaN              NaN
# 63                            NaN            NaN              NaN
# 64                            NaN            NaN              NaN
# 65                            NaN            NaN              NaN
# 66                            NaN            NaN              NaN
# 67                            NaN            NaN              NaN
# 68                            NaN            NaN              NaN
# 69                            NaN            NaN              NaN
# 70                            NaN            NaN              NaN
# 71                            NaN            NaN              NaN
# 72                            NaN            NaN              NaN
# 73                            NaN            NaN              NaN
# 74                            NaN            NaN              NaN
# 75                            NaN            NaN              NaN
# 76                            NaN            NaN              NaN
# 77                            NaN            NaN              NaN
# 78                            NaN            NaN              NaN
# 79                            NaN            NaN              NaN
# 80                            NaN            NaN              NaN
# 81                            NaN            NaN              NaN
# 82                            NaN            NaN              NaN
# 83                            NaN            NaN              NaN
# 84                            NaN            NaN              NaN
# 85                            NaN            NaN              NaN
#
#     pchic.total-cd8  pchic_support  lead.rs_id
# 0               NaN              0  rs10814917
# 1               NaN              0  rs10814917
# 2               NaN              0  rs10814917
# 3               NaN              0  rs10814917
# 4               NaN              0  rs10814917
# 5               NaN              0  rs10814917
# 6               NaN              0  rs10814917
# 7               NaN              0  rs10814917
# 8               NaN              0  rs10814917
# 9               NaN              0  rs10814917
# 10              NaN              0  rs10814917
# 11              NaN              0  rs10814917
# 12              NaN              0  rs10814917
# 13              NaN              0  rs10814917
# 14              NaN              0  rs10814917
# 15              NaN              0  rs10814917
# 16              NaN              0  rs10814917
# 17              NaN              0  rs10814917
# 18              NaN              0  rs10814917
# 19              NaN              0  rs10814917
# 20              NaN              0  rs10814917
# 21              NaN              0  rs10814917
# 22              NaN              0  rs10814917
# 23              NaN              0  rs10814917
# 24              NaN              0  rs10814917
# 25              NaN              0  rs10814917
# 26              NaN              0  rs10814917
# 27              NaN              0  rs10814917
# 28              NaN              0  rs10814917
# 29              NaN              0  rs10814917
# 30              NaN              0  rs10814917
# 31              NaN              0  rs10814917
# 32              NaN              0  rs10814917
# 33              NaN              0  rs10814917
# 34              NaN              0  rs10814917
# 35              NaN              0  rs10814917
# 36              NaN              0  rs10814917
# 37              NaN              0  rs10814917
# 38              NaN              1  rs10814917
# 39              NaN              1  rs10814917
# 40              NaN              1  rs10814917
# 41              NaN              1  rs10814917
# 42              NaN              1  rs10814917
# 43              NaN              1  rs10814917
# 44              NaN              1  rs10814917
# 45              NaN              1  rs10814917
# 46              NaN              1  rs10814917
# 47              NaN              0  rs10814917
# 48              NaN              0  rs10814917
# 49              NaN              0  rs10814917
# 50              NaN              0  rs10814917
# 51              NaN              1  rs10814917
# 52              NaN              0  rs17207042
# 53              NaN              0  rs17207042
# 54              NaN              0  rs17207042
# 55              NaN              0  rs17207042
# 56              NaN              0  rs17207042
# 57              NaN              0  rs17207042
# 58              NaN              0  rs17207042
# 59              NaN              0  rs17207042
# 60              NaN              0  rs17207042
# 61              NaN              0  rs17207042
# 62              NaN              0  rs17207042
# 63              NaN              0  rs17207042
# 64              NaN              0  rs17207042
# 65              NaN              0  rs17207042
# 66              NaN              0  rs17207042
# 67              NaN              0  rs17207042
# 68              NaN              0  rs17207042
# 69              NaN              0  rs17207042
# 70              NaN              0  rs17207042
# 71              NaN              0  rs17207042
# 72              NaN              0  rs17207042
# 73              NaN              0  rs17207042
# 74              NaN              0  rs17207042
# 75              NaN              0  rs17207042
# 76              NaN              0  rs17207042
# 77              NaN              0  rs17207042
# 78              NaN              0  rs17207042
# 79              NaN              0  rs17207042
# 80              NaN              0  rs17207042
# 81              NaN              0  rs17207042
# 82              NaN              0  rs17207042
# 83              NaN              0  rs17207042
# 84              NaN              0  rs17207042
# 85              NaN              0  rs17207042

# %% [markdown]
# #### Finemap Approach

# %%
# creating a dictionary which matches 
# hichip and pc-hic data
hichip_pchic_matches = {'monocytes': 'CM',
                        'naive-b': 'NB',
                        'total-b': 'NB',
                        'gms_merged': 'NB', 
                        'naive-cd4': 'CD4N', 
                        'total-cd4': 'CD4N', 
                        'non-activated-total-cd4': 'CD4N',
                        'naive-cd8': 'CD8N',
                        'total-cd8': 'CD8N'}

# %%
# getting a list of pc_hic files 
pc_hics = glob.glob('results/main/pc_hic/2016_javierre/processing/*.bedpe')
pc_hics += glob.glob('results/main/pc_hic/2019_jung/processing/*.bedpe')

# adding a merge id for post fixing
finemap['mid'] = range(finemap.shape[0])

# initializing the merge list and column names
pchic_merge_data = []
pchic_cols = ['chrA', 'startA', 'endA', 'chrB', 'startB', 'endB', 'score', 'pchic_cline']
hichip_bedpe_cols = ['chrA_loop', 'startA_loop', 'endA_loop',
                    'chrB_loop', 'startB_loop', 'endB_loop', 'mid']
for fn in pc_hics:
    pchic_cline = os.path.basename(fn).split('.')[0]
    if pchic_cline in hichip_pchic_matches: 
        
        # getting hichip data for the current cell line
        hichip_cline = hichip_pchic_matches[pchic_cline]
        hichip_cline_df = finemap.loc[finemap.cline_loop == hichip_cline, hichip_bedpe_cols]
        
        # loading pc-hic data for the current cell line
        pchic_cline_df = pd.read_table(fn, names=pchic_cols)
        #         pchic_cline_df.chrA = pchic_cline_df.chrA.str.replace('chr', '')
        #         pchic_cline_df.chrB = pchic_cline_df.chrB.str.replace('chr', '')
        
        # intersecting hichip and pc-hic bedpes
        hichip_cline_pbt = pbt.BedTool.from_dataframe(hichip_cline_df)
        pchic_cline_pbt = pbt.BedTool.from_dataframe(pchic_cline_df)
        both_loops = hichip_cline_pbt.pairtopair(pchic_cline_pbt)        
        both_loops = both_loops.to_dataframe(disable_auto_names=True, header=None).iloc[:, 0:15]
        
        if both_loops.shape[0] > 0: 
            pchic_merge_data.append(both_loops)
            print('overlap found: {}'.format(fn))
        else:
            print('overlap not found: {}'.format(fn))
# Out:
# overlap found: results/main/pc_hic/2016_javierre/processing/non-activated-total-cd4.bedpe
# overlap found: results/main/pc_hic/2016_javierre/processing/monocytes.bedpe
# overlap found: results/main/pc_hic/2016_javierre/processing/naive-b.bedpe
# overlap found: results/main/pc_hic/2016_javierre/processing/total-cd8.bedpe
# overlap found: results/main/pc_hic/2016_javierre/processing/total-cd4.bedpe
# overlap found: results/main/pc_hic/2016_javierre/processing/total-b.bedpe
# overlap found: results/main/pc_hic/2016_javierre/processing/naive-cd4.bedpe
# overlap found: results/main/pc_hic/2016_javierre/processing/naive-cd8.bedpe
# overlap not found: results/main/pc_hic/2019_jung/processing/gms_merged.bedpe

# %%
pchic_merge_df = pd.concat(pchic_merge_data, axis=0)
pchic_merge_df.columns = ['hichip_chrA', 'hichip_startA', 'hichip_endA',
                    'hichip_chrB', 'hichip_startB', 'hichip_endB', 'hichip_mid', 
                    'pchic_chrA', 'pchic_startA', 'pchic_endA',
                    'pchic_chrB', 'pchic_startB', 'pchic_endB', 'pchic_score', 'pchic_cline']
pchic_merge_df = pchic_merge_df.sort_values('pchic_score', ascending=False)
pchic_merge_df = pchic_merge_df.drop_duplicates(subset=['hichip_mid'], keep='first')

# creating a table of HiChIP ID versus PC-HiC cell versus score (entries) 
pchic_merge_clean = pchic_merge_df[['hichip_mid', 'pchic_score', 'pchic_cline']]
pchic_merge_clean = pchic_merge_clean.pivot(index='hichip_mid', columns='pchic_cline', values='pchic_score')
pchic_merge_clean.columns = 'pchic.' + pchic_merge_clean.columns

# merging and cleaning the merged dataset 
finemap = finemap.merge(pchic_merge_clean, left_on='mid', right_on='hichip_mid')
finemap.drop('mid', axis=1, inplace=True)

# no overlap with gms_merged so manually adding 
finemap['pchic.gms_merged'] = np.nan

# %%
# adding column to specify PC-HiC Support
pchic_support = []
for i, sr in finemap.iterrows():
    
    pchic_supp = 0 
    if sr.cline_loop == 'CD4N':
        if sr['pchic.naive-cd4'] >= 5 or sr['pchic.total-cd4'] >= 5 or sr['pchic.non-activated-total-cd4'] > 5:
            pchic_supp = 1 
            
    elif sr.cline_loop == 'CD8N':
        if sr['pchic.naive-cd8'] >= 5 or sr['pchic.total-cd8'] >= 5:
            pchic_supp = 1 
            
    elif sr.cline_loop == 'CM':
        if sr['pchic.monocytes'] >= 5:
            pchic_supp = 1             
            
    elif sr.cline_loop == 'NB':
        if sr['pchic.naive-b'] >= 5 or sr['pchic.total-b'] >= 5 or sr['pchic.gms_merged'] >= 5:
            pchic_supp = 1        
    
    pchic_support.append(pchic_supp)
        
finemap['pchic_support'] = pchic_support

# %%
# generating the hgvs id to query myvariant 
finemap['hgvs_id'] = finemap['chrA_loop'].astype(str) + ":g." + \
                        finemap['pos'].astype(str) + finemap['allele2'] + '>' + finemap['allele1']

# %%
finemap_cols = ['chrA_loop', 'startA_loop', 'endA_loop',
                'chrB_loop', 'startB_loop', 'endB_loop', 
                'pos', 'hgvs_id', 'genename', 'geneid', 'cline_loop', 'sgl_type', 'pchic.monocytes', 
                'pchic.naive-b', 'pchic.naive-cd4', 'pchic.naive-cd8',
                'pchic.non-activated-total-cd4', 'pchic.total-b',
                'pchic.total-cd4', 'pchic.total-cd8','pchic_support']

# %%
finemap_min = finemap[finemap_cols]

# %%
finemap_min.columns = ['chrA', 'startA', 'endA',
                      'chrB', 'startB', 'endB',
                      'pos', 'hgvs_id', 'genename', 'geneid', 
                      'cline', 'sgl_type', 'pchic.monocytes',
                      'pchic.naive-b', 'pchic.naive-cd4', 'pchic.naive-cd8',
                      'pchic.non-activated-total-cd4', 'pchic.total-b',
                      'pchic.total-cd4', 'pchic.total-cd8','pchic_support']

# %% [markdown]
# #### Pieqtl Approach

# %%
# create locus A columns which require startA and endA
def pos_to_bin(pos, res):
    start = int(np.floor(pos / res) * res)
    end = start + res 
    return([start, end])

lociA = pieqtl['pieQTL.Position'].apply(pos_to_bin, res=5000)
lociA = pd.DataFrame(lociA.values.tolist())
lociA.columns = ['startA', 'endA']

# create locus B columns which require startB and endB
def tss_to_bin(tss, res, slop=0):
    start = int(np.floor(tss / res) * res)
    end = start + res 
    return([start, end])

lociB = pieqtl['TSS'].apply(tss_to_bin, res=5000)
lociB = pd.DataFrame(lociB.values.tolist())
lociB.columns = ['startB', 'endB']

# create locus columns to main intersect df 
pieqtl = pd.concat([pieqtl, lociA, lociB], axis=1)

# creating a dictionary which matches 
# hichip and pc-hic data
hichip_pchic_matches = {'monocytes': 'monocyte_naive',
                        'naive-b': 'B-cell_naive',
                        'total-b': 'B-cell_naive',
                        'gms_merged': 'B-cell_naive', 
                        'naive-cd4': 'CD4_T-cell_naive', 
                        'total-cd4': 'CD4_T-cell_naive', 
                        'non-activated-total-cd4': 'CD4_T-cell_naive',
                        'naive-cd8': 'CD8_T-cell_naive',
                        'total-cd8': 'CD8_T-cell_naive'}

# %%
# getting a list of pc_hic files 
pc_hics = glob.glob('results/main/pc_hic/2016_javierre/processing/*.bedpe')
pc_hics += glob.glob('results/main/pc_hic/2019_jung/processing/*.bedpe')

# adding a merge id for post fixing
pieqtl['mid'] = range(pieqtl.shape[0])

# initializing the merge list and column names
pchic_merge_data = []
pchic_cols = ['chrA', 'startA', 'endA', 'chrB', 'startB', 'endB', 'score', 'pchic_cline']
intersect_bedpe_cols = ['CHR', 'startA', 'endA', 'CHR', 'startB', 'endB', 'mid']

for fn in pc_hics:
    
    pchic_cline = os.path.basename(fn).split('.')[0]
    if pchic_cline in hichip_pchic_matches: 
        
        # getting pieqtl data for the current cell line
        pieqtl_cline = hichip_pchic_matches[pchic_cline]
        pieqtl_cline_df = pieqtl.loc[pieqtl.cline == pieqtl_cline, intersect_bedpe_cols]
        pieqtl_cline_df.iloc[:, 0] = pieqtl_cline_df.iloc[:, 0].str.replace('chr', '')
        pieqtl_cline_df.iloc[:, 3] = pieqtl_cline_df.iloc[:, 0].str.replace('chr', '')
        
        # loading pc-hic data for the current cell line
        pchic_cline_df = pd.read_table(fn, names=pchic_cols)
        pchic_cline_df.chrA = pchic_cline_df.chrA.str.replace('chr', '')
        pchic_cline_df.chrB = pchic_cline_df.chrB.str.replace('chr', '')
        
        # intersecting pieqtl and pc-hic bedpes
        pieqtl_cline_pbt = pbt.BedTool.from_dataframe(pieqtl_cline_df)
        pchic_cline_pbt = pbt.BedTool.from_dataframe(pchic_cline_df)
        both_loops = pieqtl_cline_pbt.pairtopair(pchic_cline_pbt)        
        both_loops = both_loops.to_dataframe(disable_auto_names=True, header=None).iloc[:, 0:15]
        
        if both_loops.shape[0] > 0: 
            pchic_merge_data.append(both_loops)
            print('overlap found: {}'.format(fn))
        else:
            print('overlap not found: {}'.format(fn))
# Out:
# overlap found: results/main/pc_hic/2016_javierre/processing/non-activated-total-cd4.bedpe
# overlap found: results/main/pc_hic/2016_javierre/processing/monocytes.bedpe
# overlap found: results/main/pc_hic/2016_javierre/processing/naive-b.bedpe
# overlap found: results/main/pc_hic/2016_javierre/processing/total-cd8.bedpe
# overlap found: results/main/pc_hic/2016_javierre/processing/total-cd4.bedpe
# overlap found: results/main/pc_hic/2016_javierre/processing/total-b.bedpe
# overlap found: results/main/pc_hic/2016_javierre/processing/naive-cd4.bedpe
# overlap found: results/main/pc_hic/2016_javierre/processing/naive-cd8.bedpe
# overlap not found: results/main/pc_hic/2019_jung/processing/gms_merged.bedpe

# %%
pchic_merge_df = pd.concat(pchic_merge_data, axis=0)
pchic_merge_df.columns = ['hichip_chrA', 'hichip_startA', 'hichip_endA',
                    'hichip_chrB', 'hichip_startB', 'hichip_endB', 'hichip_mid', 
                    'pchic_chrA', 'pchic_startA', 'pchic_endA',
                    'pchic_chrB', 'pchic_startB', 'pchic_endB', 'pchic_score', 'pchic_cline']
pchic_merge_df = pchic_merge_df.sort_values('pchic_score', ascending=False)
pchic_merge_df = pchic_merge_df.drop_duplicates(subset=['hichip_mid'], keep='first')

# creating a table of HiChIP ID versus PC-HiC cell versus score (entries) 
pchic_merge_clean = pchic_merge_df[['hichip_mid', 'pchic_score', 'pchic_cline']]
pchic_merge_clean = pchic_merge_clean.pivot(index='hichip_mid', columns='pchic_cline', values='pchic_score')
pchic_merge_clean.columns = 'pchic.' + pchic_merge_clean.columns

# merging and cleaning the merged dataset 
pieqtl = pieqtl.merge(pchic_merge_clean, left_on='mid', right_on='hichip_mid')
pieqtl.drop('mid', axis=1, inplace=True)

pchic_support = []
for i, sr in pieqtl.iterrows():
    
    pchic_supp = 0 
    if sr.cline == 'CD4_T-cell_naive':
        if sr['pchic.naive-cd4'] >= 5 or sr['pchic.total-cd4'] >= 5 or sr['pchic.non-activated-total-cd4'] > 5:
            pchic_supp = 1 
    elif sr.cline == 'CD8_T-cell_naive':
        if sr['pchic.naive-cd8'] >= 5 or sr['pchic.total-cd8'] >= 5:
            pchic_supp = 1 
    elif sr.cline == 'monocyte_naive':
        if sr['pchic.monocytes'] >= 5:
            pchic_supp = 1             
            
    elif sr.cline == 'B-cell_naive':
        if sr['pchic.naive-b'] >= 5 or sr['pchic.total-b'] >= 5: #or sr['pchic.gms_merged'] >= 5:
            pchic_supp = 1        
            
    pchic_support.append(pchic_supp)
        
pieqtl['pchic_support'] = pchic_support

# %%
# generating the hgvs id to query myvariant 
pieqtl['hgvs_id'] = pieqtl['CHR'].astype(str) + ":g." + \
                        pieqtl['POS'].astype(str) + pieqtl['ref'] + '>' + pieqtl['alt']

# %%
pieqtl_cols = ['CHR', 'startA', 'endA',
               'CHR', 'startB', 'endB',
               'POS', 'hgvs_id', 'genename', 'geneid', 'cline', 'sgl_type', 'pchic.monocytes',
                'pchic.naive-b', 'pchic.naive-cd4', 'pchic.naive-cd8',
                'pchic.non-activated-total-cd4', 'pchic.total-b',
                'pchic.total-cd4', 'pchic.total-cd8','pchic_support']

# %%
pieqtl_min = pieqtl[pieqtl_cols]

# %%
pieqtl_min.columns = ['chrA', 'startA', 'endA',
                      'chrB', 'startB', 'endB',
                      'pos', 'hgvs_id', 'genename', 'geneid', 
                      'cline', 'sgl_type', 'pchic.monocytes',
                      'pchic.naive-b', 'pchic.naive-cd4', 'pchic.naive-cd8',
                      'pchic.non-activated-total-cd4', 'pchic.total-b',
                      'pchic.total-cd4', 'pchic.total-cd8','pchic_support']

# %% [markdown]
# ## Concating and comparing

# %%
genes_fn = 'results/refs/gencode/v30/gencode.v30.annotation.grch37.bed'

# load the gencode coords
cols = ['chrom', 'start', 'end', 'strand', 'type', 'gene_id', 'gene_name', 'subtype']
gencode = pd.read_table(genes_fn, header=None, names=cols)

# extract just the genes
genes_df = gencode.loc[gencode['type'].isin(['gene'])]
genes_df = genes_df.loc[~genes_df.duplicated(subset='gene_id'), :]
genes_df.loc[:, 'chrom'] = genes_df['chrom'].astype(str)
# genes_df = genes_df.iloc[:, [0,1,2,6,5,3]]

# %%
# combining finemap nd pieqtls first
agg_sgls = pd.concat([finemap_min, pieqtl_min])
agg_sgls = agg_sgls.merge(genes_df[['gene_id', 'subtype']], left_on='geneid', right_on='gene_id')

# %%
import myvariant

# generate a dictionary of hgvs id to rsid
mv = myvariant.MyVariantInfo()
query = mv.getvariants(agg_sgls.hgvs_id, fields=['dbsnp.rsid'])

hgvs_to_rsid = {}
for rec in query:
    
    if 'dbsnp' in rec:
        hgvs_to_rsid[rec['query']] = rec['dbsnp']['rsid']
    else:
        hgvs_to_rsid[rec['query']] = 'Not Found'

agg_sgls['rsid'] = agg_sgls['hgvs_id'].replace(hgvs_to_rsid)
# Out:
# querying 1-355...done.

# %%
agg_sgls
# Out:
#       chrA     startA       endA   chrB     startB       endB        pos  \
# 0     chr1   19810000   19815000   chr1   19970000   19975000   19972330
# 1     chr1   19810000   19815000   chr1   19970000   19975000   19972330
# 2    chr10  124125000  124130000  chr10  124765000  124770000  124128690
# 3    chr11    1855000    1860000  chr11    2020000    2025000    2021075
# 4    chr11    1855000    1860000  chr11    2020000    2025000    2021075
# ..     ...        ...        ...    ...        ...        ...        ...
# 350   chr6   31145000   31150000   chr6   31125000   31130000   31149520
# 351   chr6   32220000   32225000   chr6   32335000   32340000   32224388
# 352   chr6   32220000   32225000   chr6   32335000   32340000   32224388
# 353   chr6   26535000   26540000   chr6   26420000   26425000   26537801
# 354   chr6   30040000   30045000   chr6   30025000   30030000   30042955
#
#                   hgvs_id    genename           geneid             cline  \
# 0      chr1:g.19972330G>A  AL391883.1  ENSG00000235434              CD4N
# 1      chr1:g.19972330G>A  AL391883.1  ENSG00000235434              CD8N
# 2    chr10:g.124128690T>C     RF00019  ENSG00000199466              CD8N
# 3      chr11:g.2021075C>T     MIR4298  ENSG00000264493              CD4N
# 4      chr11:g.2021075C>T     MIR4298  ENSG00000264493                NB
# ..                    ...         ...              ...               ...
# 350    chr6:g.31149520G>A      CCHCR1  ENSG00000204536  CD4_T-cell_naive
# 351    chr6:g.32224388C>A       TSBP1  ENSG00000204296      B-cell_naive
# 352    chr6:g.32224388C>A       TSBP1  ENSG00000204296      B-cell_naive
# 353    chr6:g.26537801G>A     BTN2A3P  ENSG00000124549  CD8_T-cell_naive
# 354    chr6:g.30042955C>T    ZNRD1ASP  ENSG00000204623  CD4_T-cell_naive
#
#     sgl_type  pchic.monocytes  pchic.naive-b  pchic.naive-cd4  \
# 0    finemap              NaN            NaN        16.519501
# 1    finemap              NaN            NaN              NaN
# 2    finemap              NaN            NaN              NaN
# 3    finemap              NaN            NaN         3.748032
# 4    finemap              NaN            NaN              NaN
# ..       ...              ...            ...              ...
# 350   pieqtl              NaN            NaN              NaN
# 351   pieqtl              NaN       6.253983              NaN
# 352   pieqtl              NaN       6.253983              NaN
# 353   pieqtl              NaN            NaN              NaN
# 354   pieqtl              NaN            NaN         6.144920
#
#      pchic.naive-cd8  pchic.non-activated-total-cd4  pchic.total-b  \
# 0                NaN                            NaN            NaN
# 1          14.945686                            NaN            NaN
# 2           7.879563                            NaN            NaN
# 3                NaN                            NaN            NaN
# 4                NaN                            NaN       3.428174
# ..               ...                            ...            ...
# 350              NaN                       2.386576            NaN
# 351              NaN                            NaN            NaN
# 352              NaN                            NaN            NaN
# 353         2.169706                            NaN            NaN
# 354              NaN                            NaN            NaN
#
#      pchic.total-cd4  pchic.total-cd8  pchic_support          gene_id  \
# 0                NaN              NaN              1  ENSG00000235434
# 1                NaN              NaN              1  ENSG00000235434
# 2                NaN              NaN              1  ENSG00000199466
# 3                NaN              NaN              0  ENSG00000264493
# 4                NaN              NaN              0  ENSG00000264493
# ..               ...              ...            ...              ...
# 350              NaN              NaN              0  ENSG00000204536
# 351              NaN              NaN              1  ENSG00000204296
# 352              NaN              NaN              1  ENSG00000204296
# 353              NaN              NaN              0  ENSG00000124549
# 354              NaN              NaN              1  ENSG00000204623
#
#                                 subtype        rsid
# 0                             antisense  rs79540600
# 1                             antisense  rs79540600
# 2                              misc_RNA  rs11816578
# 3                                 miRNA   rs2107425
# 4                                 miRNA   rs2107425
# ..                                  ...         ...
# 350                      protein_coding   rs3130508
# 351                      protein_coding   rs9268005
# 352                      protein_coding   rs9268005
# 353  transcribed_unprocessed_pseudogene   rs6920256
# 354      transcribed_unitary_pseudogene   rs1150736
#
# [355 rows x 24 columns]

# %%
# add the colocs 
agg_sgls.drop('hgvs_id', axis=1, inplace=True)
tmp_coloc_min = coloc_min.merge(genes_df[['gene_id', 'subtype']], left_on='geneid', right_on='gene_id')
agg_sgls = pd.concat([agg_sgls, tmp_coloc_min])

# %%
agg_gene_grps = agg_sgls.groupby('subtype')

# %%
list(agg_gene_grps.groups.keys())
# Out:
# ['antisense',
#  'lincRNA',
#  'miRNA',
#  'misc_RNA',
#  'processed_pseudogene',
#  'protein_coding',
#  'snRNA',
#  'snoRNA',
#  'transcribed_unitary_pseudogene',
#  'transcribed_unprocessed_pseudogene',
#  'unprocessed_pseudogene']

# %%
# creating a dictionary which matches 
# hichip and pc-hic data
dice_to_sgl_names = {'CM': 'monocyte_naive',
                        'NB': 'B-cell_naive', 
                        'CD4N': 'CD4_T-cell_naive',
                        'CD8N': 'CD8_T-cell_naive'}

# %%
agg_sgls.cline = agg_sgls.cline.replace(dice_to_sgl_names)

# %% [markdown]
# ## Focusing on protein coding genes

# %%
prots_only = agg_gene_grps.get_group('protein_coding')
prots_only.sort_values(['geneid', 'cline', 'sgl_type'], inplace=True)
# Out:
# /mnt/hpcscratch/jreyna//ipykernel_122078/4241751256.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prots_only.sort_values(['geneid', 'cline', 'sgl_type'], inplace=True)

# %%
sig_prots = prots_only.loc[prots_only.pchic_support == 1]

# %%
g = sig_prots.groupby(['cline', 'sgl_type'])
sgl_count_per_cell = g.genename.value_counts()
sgl_count_per_cell = sgl_count_per_cell.to_frame()
sgl_count_per_cell.columns = ['sgl_counts']
sgl_count_per_cell.reset_index(inplace=True)

# %%
sgl_count_per_cell.sort_values('sgl_counts', ascending=False)
# Out:
#                cline sgl_type    genename  sgl_counts
# 30  CD8_T-cell_naive   pieqtl        LST1          25
# 31  CD8_T-cell_naive   pieqtl       BACH2          18
# 32  CD8_T-cell_naive   pieqtl     ZKSCAN4          13
# 4       B-cell_naive   pieqtl      BTN2A1          12
# 8   CD4_T-cell_naive    coloc       GLIS3          10
# 33  CD8_T-cell_naive   pieqtl      LY6G5B           9
# 42    monocyte_naive   pieqtl      TRIM27           8
# 5       B-cell_naive   pieqtl       BTNL2           7
# 43    monocyte_naive   pieqtl      LY6G5C           4
# 18  CD4_T-cell_naive   pieqtl      LY6G5C           2
# 1       B-cell_naive  finemap        SAE1           2
# 22  CD8_T-cell_naive  finemap        TYK2           2
# 34  CD8_T-cell_naive   pieqtl      BTN3A2           2
# 35  CD8_T-cell_naive   pieqtl        RMI2           2
# 36    monocyte_naive  finemap        TYK2           2
# 0       B-cell_naive  finemap  AC008755.1           2
# 44    monocyte_naive   pieqtl       FLOT1           2
# 7       B-cell_naive   pieqtl       TSBP1           2
# 6       B-cell_naive   pieqtl        LST1           2
# 2       B-cell_naive  finemap        TYK2           2
# 38    monocyte_naive  finemap      CLEC2B           1
# 37    monocyte_naive  finemap      CLEC1A           1
# 39    monocyte_naive  finemap      CLEC7A           1
# 29  CD8_T-cell_naive  finemap       SEH1L           1
# 41    monocyte_naive  finemap       SGF29           1
# 45    monocyte_naive   pieqtl      BTN3A2           1
# 46    monocyte_naive   pieqtl     SLC22A5           1
# 40    monocyte_naive  finemap       KLRF2           1
# 24  CD8_T-cell_naive  finemap       DCAF5           1
# 28  CD8_T-cell_naive  finemap       RPL37           1
# 15  CD4_T-cell_naive  finemap     SLC27A5           1
# 3       B-cell_naive  finemap       DCAF5           1
# 9   CD4_T-cell_naive  finemap     CLEC12A           1
# 10  CD4_T-cell_naive  finemap        FYB1           1
# 11  CD4_T-cell_naive  finemap    MAPKAPK5           1
# 12  CD4_T-cell_naive  finemap      PTGER4           1
# 13  CD4_T-cell_naive  finemap      RICTOR           1
# 14  CD4_T-cell_naive  finemap       RPL37           1
# 16  CD4_T-cell_naive  finemap       TTC33           1
# 27  CD8_T-cell_naive  finemap      PTGER4           1
# 17  CD4_T-cell_naive  finemap        TYK2           1
# 19  CD4_T-cell_naive   pieqtl        AIF1           1
# 20  CD4_T-cell_naive   pieqtl       BACH2           1
# 21  CD4_T-cell_naive   pieqtl      BTN3A2           1
# 23  CD8_T-cell_naive  finemap    CDC42EP1           1
# 25  CD8_T-cell_naive  finemap        FYB1           1
# 26  CD8_T-cell_naive  finemap    MAPKAPK5           1
# 47    monocyte_naive   pieqtl       ZGLP1           1

# %%
sgl_count_per_cell.genename.nunique()
# Out:
# 35

# %% [markdown]
# ## Intersecting Dice Gene Expression

# %%
ge_list = ['results/main/dice_gene_expression/CD4N_TPM.csv', 
           'results/main/dice_gene_expression/CD8N_TPM.csv', 
           'results/main/dice_gene_expression/CM_TPM.csv', 
           'results/main/dice_gene_expression/NB_TPM.csv']

# %%
dice_expr_list = []
for ge_fn in ge_list:
    print(ge_fn)

    df = pd.read_table(ge_fn, sep=',')
    cline = ge_fn.split('/')[-1].split('_')[0]
    df['cline'] = dice_to_sgl_names[cline]
    
    df.drop(['Transcript_Length(bp)', 'Additional_annotations'], axis=1, inplace=True)
    df.set_index('Feature_name', inplace=True)
    df = df.median(axis=1).to_frame()
    df.columns = ['ge.' + dice_to_sgl_names[cline]]
    
    dice_expr_list.append(df)

# concat all of the gene expression data
dice_expr = pd.concat(dice_expr_list, axis=1)
dice_expr.index = dice_expr.index.str.replace('\.[A-Za-z0-9_-]*$', '')
# Out:
# results/main/dice_gene_expression/CD4N_TPM.csv
# /mnt/hpcscratch/jreyna//ipykernel_122078/4113014675.py:11: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df = df.median(axis=1).to_frame()
# results/main/dice_gene_expression/CD8N_TPM.csv
# /mnt/hpcscratch/jreyna//ipykernel_122078/4113014675.py:11: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df = df.median(axis=1).to_frame()
# results/main/dice_gene_expression/CM_TPM.csv
# /mnt/hpcscratch/jreyna//ipykernel_122078/4113014675.py:11: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df = df.median(axis=1).to_frame()
# results/main/dice_gene_expression/NB_TPM.csv
# /mnt/hpcscratch/jreyna//ipykernel_122078/4113014675.py:11: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df = df.median(axis=1).to_frame()
# /mnt/hpcscratch/jreyna//ipykernel_122078/4113014675.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   dice_expr.index = dice_expr.index.str.replace('\.[A-Za-z0-9_-]*$', '')

# %%
sig_prots = sig_prots.merge(dice_expr, left_on='geneid', right_index=True)

# %%
# calculating the specfic expression approach
ge_cell_specific = []
for i, sr in sig_prots.iterrows():
    
    ge_spec = 0
    if sr.cline == 'CD4_T-cell_naive' and sr['ge.CD4_T-cell_naive'] > 8:
        ge_spec = 1 
        
    elif sr.cline == 'CD8_T-cell_naive' and sr['ge.CD8_T-cell_naive'] > 8:
        ge_spec = 1 
        
    elif sr.cline == 'monocyte_naive' and sr['ge.monocyte_naive'] > 8:
        ge_spec = 1 
        
    elif sr.cline == 'B-cell_naive' and sr['ge.B-cell_naive'] > 8:
        ge_spec = 1 
    
    ge_cell_specific.append(ge_spec)
        
sig_prots['ge_support'] = ge_cell_specific

# %%
# making a final table
expr_sig_prots = sig_prots.loc[sig_prots.ge_support == 1]
expr_sig_prots.sort_values(['genename', 'cline'], inplace=True)
# Out:
# /mnt/hpcscratch/jreyna//ipykernel_122078/1061568006.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   expr_sig_prots.sort_values(['genename', 'cline'], inplace=True)

# %%
single_reps = expr_sig_prots.drop_duplicates(['genename', 'cline'])
pd.set_option('display.max_rows', None)
display(single_reps)
pd.set_option('display.max_rows', 100)
# Out:
#       chrA     startA       endA   chrB     startB       endB        pos  \
# 79   chr19   47110000   47115000  chr19   47220000   47225000   47223949
# 240   chr6   31800000   31805000   chr6   31580000   31585000   31801233
# 265   chr6   90975000   90980000   chr6   91005000   91010000   90976768
# 261   chr6   90885000   90890000   chr6   91005000   91010000   90886824
# 320   chr6   26530000   26535000   chr6   26455000   26460000   26533664
# 337   chr6   26500000   26505000   chr6   26365000   26370000   26501768
# 339   chr6   26595000   26600000   chr6   26365000   26370000   26598004
# 338   chr6   26595000   26600000   chr6   26365000   26370000   26598004
# 107  chr12    9870000    9875000  chr12   10280000   10285000   10282239
# 112  chr12   10130000   10135000  chr12   10280000   10285000   10282239
# 51   chr14   69150000   69155000  chr14   69260000   69265000   69260849
# 52   chr14   69150000   69155000  chr14   69245000   69250000   69247359
# 130   chr6   30760000   30765000   chr6   30710000   30715000   30763004
# 86    chr5   39210000   39215000   chr5   39270000   39275000   39211189
# 87    chr5   39210000   39215000   chr5   39270000   39275000   39211189
# 166   chr6   31540000   31545000   chr6   31550000   31555000   31542308
# 141   chr6   31505000   31510000   chr6   31550000   31555000   31509284
# 185   chr6   31780000   31785000   chr6   31635000   31640000   31783208
# 34   chr12  111840000  111845000  chr12  111880000  111885000  111884608
# 35   chr12  111840000  111845000  chr12  111880000  111885000  111884608
# 88    chr5   39210000   39215000   chr5   40675000   40680000   39211189
# 89    chr5   39210000   39215000   chr5   40675000   40680000   39211189
# 85    chr5   39070000   39075000   chr5   39210000   39215000   39211189
# 95    chr5   39210000   39215000   chr5   40835000   40840000   39211189
# 96    chr5   39210000   39215000   chr5   40835000   40840000   39211189
# 77   chr19   47110000   47115000  chr19   47220000   47225000   47223949
# 69   chr18   12775000   12780000  chr18   12945000   12950000   12778715
# 64   chr16   28505000   28510000  chr16   28550000   28555000   28505660
# 312   chr6   28860000   28865000   chr6   28890000   28895000   28863264
# 72   chr19   10380000   10385000  chr19   10510000   10515000   10512911
# 70   chr19   10380000   10385000  chr19   10510000   10515000   10512911
# 71   chr19   10380000   10385000  chr19   10510000   10515000   10512911
# 73   chr19   10380000   10385000  chr19   10510000   10515000   10512911
# 297   chr6   28105000   28110000   chr6   28225000   28230000   28106141
#
#        genename           geneid             cline sgl_type  pchic.monocytes  \
# 79   AC008755.1  ENSG00000130749      B-cell_naive  finemap              NaN
# 240        AIF1  ENSG00000204472  CD4_T-cell_naive   pieqtl              NaN
# 265       BACH2  ENSG00000112182  CD4_T-cell_naive   pieqtl              NaN
# 261       BACH2  ENSG00000112182  CD8_T-cell_naive   pieqtl              NaN
# 320      BTN2A1  ENSG00000112763      B-cell_naive   pieqtl              NaN
# 337      BTN3A2  ENSG00000186470  CD4_T-cell_naive   pieqtl              NaN
# 339      BTN3A2  ENSG00000186470  CD8_T-cell_naive   pieqtl              NaN
# 338      BTN3A2  ENSG00000186470    monocyte_naive   pieqtl        10.592087
# 107      CLEC2B  ENSG00000110852    monocyte_naive  finemap        10.448108
# 112      CLEC7A  ENSG00000172243    monocyte_naive  finemap         7.144294
# 51        DCAF5  ENSG00000139990      B-cell_naive  finemap              NaN
# 52        DCAF5  ENSG00000139990  CD8_T-cell_naive  finemap              NaN
# 130       FLOT1  ENSG00000137312    monocyte_naive   pieqtl         8.978399
# 86         FYB1  ENSG00000082074  CD4_T-cell_naive  finemap              NaN
# 87         FYB1  ENSG00000082074  CD8_T-cell_naive  finemap              NaN
# 166        LST1  ENSG00000204482      B-cell_naive   pieqtl              NaN
# 141        LST1  ENSG00000204482  CD8_T-cell_naive   pieqtl              NaN
# 185      LY6G5B  ENSG00000240053  CD8_T-cell_naive   pieqtl              NaN
# 34     MAPKAPK5  ENSG00000089022  CD4_T-cell_naive  finemap              NaN
# 35     MAPKAPK5  ENSG00000089022  CD8_T-cell_naive  finemap              NaN
# 88       PTGER4  ENSG00000171522  CD4_T-cell_naive  finemap              NaN
# 89       PTGER4  ENSG00000171522  CD8_T-cell_naive  finemap              NaN
# 85       RICTOR  ENSG00000164327  CD4_T-cell_naive  finemap              NaN
# 95        RPL37  ENSG00000145592  CD4_T-cell_naive  finemap              NaN
# 96        RPL37  ENSG00000145592  CD8_T-cell_naive  finemap              NaN
# 77         SAE1  ENSG00000142230      B-cell_naive  finemap              NaN
# 69        SEH1L  ENSG00000085415  CD8_T-cell_naive  finemap              NaN
# 64        SGF29  ENSG00000176476    monocyte_naive  finemap         6.885638
# 312      TRIM27  ENSG00000204713    monocyte_naive   pieqtl        39.977165
# 72         TYK2  ENSG00000105397      B-cell_naive  finemap              NaN
# 70         TYK2  ENSG00000105397  CD4_T-cell_naive  finemap              NaN
# 71         TYK2  ENSG00000105397  CD8_T-cell_naive  finemap              NaN
# 73         TYK2  ENSG00000105397    monocyte_naive  finemap        23.980259
# 297     ZKSCAN4  ENSG00000187626  CD8_T-cell_naive   pieqtl              NaN
#
#      pchic.naive-b  pchic.naive-cd4  pchic.naive-cd8  \
# 79        8.163704              NaN              NaN
# 240            NaN         6.593487              NaN
# 265            NaN         9.281679              NaN
# 261            NaN              NaN        14.328445
# 320            NaN              NaN              NaN
# 337            NaN              NaN              NaN
# 339            NaN              NaN              NaN
# 338            NaN              NaN              NaN
# 107            NaN              NaN              NaN
# 112            NaN              NaN              NaN
# 51             NaN              NaN              NaN
# 52             NaN              NaN         7.957766
# 130            NaN              NaN              NaN
# 86             NaN        21.558387              NaN
# 87             NaN              NaN              NaN
# 166       7.055537              NaN              NaN
# 141            NaN              NaN              NaN
# 185            NaN              NaN              NaN
# 34             NaN         6.476676              NaN
# 35             NaN              NaN         5.869683
# 88             NaN              NaN              NaN
# 89             NaN              NaN              NaN
# 85             NaN         7.819805              NaN
# 95             NaN              NaN              NaN
# 96             NaN              NaN              NaN
# 77        8.163704              NaN              NaN
# 69             NaN              NaN              NaN
# 64             NaN              NaN              NaN
# 312            NaN              NaN              NaN
# 72             NaN              NaN              NaN
# 70             NaN        28.002280              NaN
# 71             NaN              NaN        25.899873
# 73             NaN              NaN              NaN
# 297            NaN              NaN              NaN
#
#      pchic.non-activated-total-cd4  pchic.total-b  pchic.total-cd4  \
# 79                             NaN            NaN              NaN
# 240                            NaN            NaN              NaN
# 265                            NaN            NaN              NaN
# 261                            NaN            NaN              NaN
# 320                            NaN       5.462889              NaN
# 337                      11.277539            NaN              NaN
# 339                            NaN            NaN              NaN
# 338                            NaN            NaN              NaN
# 107                            NaN            NaN              NaN
# 112                            NaN            NaN              NaN
# 51                             NaN       6.451721              NaN
# 52                             NaN            NaN              NaN
# 130                            NaN            NaN              NaN
# 86                             NaN            NaN              NaN
# 87                             NaN            NaN              NaN
# 166                            NaN            NaN              NaN
# 141                            NaN            NaN              NaN
# 185                            NaN            NaN              NaN
# 34                             NaN            NaN              NaN
# 35                             NaN            NaN              NaN
# 88                        6.886014            NaN              NaN
# 89                             NaN            NaN              NaN
# 85                             NaN            NaN              NaN
# 95                             NaN            NaN         6.320798
# 96                             NaN            NaN              NaN
# 77                             NaN            NaN              NaN
# 69                             NaN            NaN              NaN
# 64                             NaN            NaN              NaN
# 312                            NaN            NaN              NaN
# 72                             NaN      18.161489              NaN
# 70                             NaN            NaN              NaN
# 71                             NaN            NaN              NaN
# 73                             NaN            NaN              NaN
# 297                            NaN            NaN              NaN
#
#      pchic.total-cd8  pchic_support          gene_id         subtype  \
# 79               NaN              1  ENSG00000130749  protein_coding
# 240              NaN              1  ENSG00000204472  protein_coding
# 265              NaN              1  ENSG00000112182  protein_coding
# 261              NaN              1  ENSG00000112182  protein_coding
# 320              NaN              1  ENSG00000112763  protein_coding
# 337              NaN              1  ENSG00000186470  protein_coding
# 339        11.091761              1  ENSG00000186470  protein_coding
# 338              NaN              1  ENSG00000186470  protein_coding
# 107              NaN              1  ENSG00000110852  protein_coding
# 112              NaN              1  ENSG00000172243  protein_coding
# 51               NaN              1  ENSG00000139990  protein_coding
# 52               NaN              1  ENSG00000139990  protein_coding
# 130              NaN              1  ENSG00000137312  protein_coding
# 86               NaN              1  ENSG00000082074  protein_coding
# 87         20.635628              1  ENSG00000082074  protein_coding
# 166              NaN              1  ENSG00000204482  protein_coding
# 141        15.927181              1  ENSG00000204482  protein_coding
# 185         8.653621              1  ENSG00000240053  protein_coding
# 34               NaN              1  ENSG00000089022  protein_coding
# 35               NaN              1  ENSG00000089022  protein_coding
# 88               NaN              1  ENSG00000171522  protein_coding
# 89          5.316926              1  ENSG00000171522  protein_coding
# 85               NaN              1  ENSG00000164327  protein_coding
# 95               NaN              1  ENSG00000145592  protein_coding
# 96          7.538688              1  ENSG00000145592  protein_coding
# 77               NaN              1  ENSG00000142230  protein_coding
# 69          6.751382              1  ENSG00000085415  protein_coding
# 64               NaN              1  ENSG00000176476  protein_coding
# 312              NaN              1  ENSG00000204713  protein_coding
# 72               NaN              1  ENSG00000105397  protein_coding
# 70               NaN              1  ENSG00000105397  protein_coding
# 71               NaN              1  ENSG00000105397  protein_coding
# 73               NaN              1  ENSG00000105397  protein_coding
# 297         9.963371              1  ENSG00000187626  protein_coding
#
#             rsid lead.rs_id  ge.CD4_T-cell_naive  ge.CD8_T-cell_naive  \
# 79      rs313841        NaN            22.902918            24.631782
# 240    rs2736430        NaN           101.321612           135.829169
# 265   rs72928038        NaN           111.125622           111.144486
# 261   rs10806423        NaN           111.125622           111.144486
# 320   rs10946834        NaN           113.796337           119.287660
# 337    rs2295593        NaN           186.095117           175.180214
# 339    rs4634439        NaN           186.095117           175.180214
# 338    rs4634439        NaN           186.095117           175.180214
# 107  rs113895413        NaN           176.405352           124.095507
# 112  rs113895413        NaN             1.685681             1.659372
# 51     rs3809391        NaN           111.085749           111.081454
# 52     rs8020118        NaN           111.085749           111.081454
# 130    rs3131059        NaN           117.308746            81.526061
# 86      rs696746        NaN           794.220497           568.187355
# 87      rs696746        NaN           794.220497           568.187355
# 166    rs1799964        NaN            13.131824            12.628667
# 141    rs3130059        NaN            13.131824            12.628667
# 185    rs1008438        NaN            28.992330            23.455943
# 34     rs3184504        NaN            31.370502            28.102476
# 35     rs3184504        NaN            31.370502            28.102476
# 88      rs696746        NaN           255.931908           221.764677
# 89      rs696746        NaN           255.931908           221.764677
# 85      rs696746        NaN           112.257733            93.860549
# 95      rs696746        NaN           615.172190           612.288973
# 96      rs696746        NaN           615.172190           612.288973
# 77      rs313841        NaN           106.712456            94.965155
# 69     rs2847278        NaN            14.079218            13.644608
# 64      rs151234        NaN            45.330260            46.706316
# 312    rs3135315        NaN            29.687826            28.378294
# 72    rs11879191        NaN            64.579009            85.104597
# 70    rs11879191        NaN            64.579009            85.104597
# 71    rs11879191        NaN            64.579009            85.104597
# 73    rs11879191        NaN            64.579009            85.104597
# 297    rs6941992        NaN            12.902640            12.451046
#
#      ge.monocyte_naive  ge.B-cell_naive  ge_support
# 79           13.804148        19.079346           1
# 240        1410.817016         1.253391           1
# 265           0.129748       236.421361           1
# 261           0.129748       236.421361           1
# 320          63.928445        83.106333           1
# 337          40.001593        50.623978           1
# 339          40.001593        50.623978           1
# 338          40.001593        50.623978           1
# 107         123.771034       166.212713           1
# 112         614.073122         0.651149           1
# 51           45.307037        69.980059           1
# 52           45.307037        69.980059           1
# 130         121.155659        35.116599           1
# 86          303.627988         0.786554           1
# 87          303.627988         0.786554           1
# 166         510.889497        13.423985           1
# 141         510.889497        13.423985           1
# 185          19.860914        20.422668           1
# 34           13.387579        22.340228           1
# 35           13.387579        22.340228           1
# 88           87.012827        99.552626           1
# 89           87.012827        99.552626           1
# 85           33.878319       113.329213           1
# 95          237.465087       344.726011           1
# 96          237.465087       344.726011           1
# 77           39.579214        31.287553           1
# 69            9.442086        19.751648           1
# 64           18.358804        22.257813           1
# 312          17.360334        18.889824           1
# 72          132.338864        71.512930           1
# 70          132.338864        71.512930           1
# 71          132.338864        71.512930           1
# 73          132.338864        71.512930           1
# 297           2.905401         7.080967           1

# %% [markdown]
# ## Comparing this final list to a consensus gene set

# %%
consensus_genes = pd.read_table('results/main/gene_lists/consensus_gene_list.txt', squeeze=True)
consensus_genes = set(consensus_genes.values.tolist())
# Out:
# /mnt/hpcscratch/jreyna//ipykernel_122078/2742499565.py:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   consensus_genes = pd.read_table('results/main/gene_lists/consensus_gene_list.txt', squeeze=True)

# %%
consensus_genes
# Out:
# {"'-",
#  'ABCC8',
#  'AC002378.1',
#  'AC080079.1',
#  'ACAP1',
#  'ACE',
#  'ACOXL',
#  'ACP1',
#  'ACSL1',
#  'ADAD1',
#  'ADAM30',
#  'ADAMTS14',
#  'ADCY7',
#  'ADGRL2',
#  'ADIPOQ',
#  'AFF3',
#  'AGO2',
#  'AGT',
#  'AGTR1',
#  'AHR',
#  'AIMP1P2',
#  'AIRE',
#  'AKR1B1',
#  'AKT2',
#  'AL049612.1',
#  'AL163932.1',
#  'AL596442.1',
#  'ALB',
#  'ALDH7A1P4',
#  'AMBP',
#  'ANKRD50',
#  'ANKRD55',
#  'AOC3',
#  'AP4B1-AS1',
#  'APOA1',
#  'ARHGAP27P2',
#  'ARL8B',
#  'ASCL2',
#  'ATG16L1',
#  'ATP6V1G3',
#  'ATXN2',
#  'ATXN2L',
#  'BACH2',
#  'BAD',
#  'BATF3',
#  'BCAR1',
#  'BCL2L15',
#  'BDNF',
#  'BGLAP',
#  'BTN2A3P',
#  'BTNL2',
#  'C1QTNF6',
#  'C1orf141',
#  'C4A',
#  'C6orf15',
#  'CALCR',
#  'CAMK4',
#  'CAMSAP2',
#  'CAPN10',
#  'CAPSL',
#  'CARD9',
#  'CBX3P1',
#  'CCL2',
#  'CCR12P',
#  'CCR5',
#  'CCR7',
#  'CCRL2',
#  'CD226',
#  'CD6',
#  'CD69',
#  'CD79A',
#  'CDC34',
#  'CDKAL1',
#  'CDKN1C',
#  'CDKN2B-AS1',
#  'CEL',
#  'CENPU',
#  'CENPW',
#  'CETP',
#  'CFB',
#  'CFTR',
#  'CLEC16A',
#  'CLEC2D',
#  'CLN3',
#  'COBL',
#  'COL11A2P1',
#  'COLEC10',
#  'CPE',
#  'CRB1',
#  'CRP',
#  'CSN2',
#  'CST3',
#  'CTLA4',
#  'CTRB1',
#  'CTRB2',
#  'CTSB',
#  'CTSH',
#  'CUX2',
#  'CXCL10',
#  'CYP27B1',
#  'CYTL1',
#  'DAG1',
#  'DCTD',
#  'DEXI',
#  'DGKA',
#  'DGKQ',
#  'DLK1',
#  'DMRTA1',
#  'DNAH2',
#  'DNAJC3',
#  'DPP4',
#  'EEF1A1P27',
#  'EFR3B',
#  'EFS',
#  'EIF2AK3',
#  'EIF4A1P4',
#  'EMSY',
#  'ENPP1',
#  'ERAP2',
#  'ERBB3',
#  'EXOC2',
#  'EYS',
#  'FADS1',
#  'FADS2',
#  'FAP',
#  'FARP2',
#  'FASLG',
#  'FCGR3A',
#  'FGF3',
#  'FGF4',
#  'FGFR3',
#  'FKBP1A',
#  'FLI1',
#  'FNBP1',
#  'FOSL2',
#  'FOXP3',
#  'FSTL4',
#  'FTO',
#  'FUT2',
#  'G6PC2',
#  'GAB3',
#  'GABRA2',
#  'GAD1',
#  'GAD2',
#  'GATA3',
#  'GATD3A',
#  'GCG',
#  'GCGR',
#  'GCK',
#  'GH1',
#  'GLIS3',
#  'GLP1R',
#  'GLRA3',
#  'GP2',
#  'GPD2',
#  'GPR183',
#  'GPR35',
#  'GRB7',
#  'GSDMB',
#  'GTF3C5',
#  'H19',
#  'HBA1',
#  'HCG21',
#  'HCP5',
#  'HECW1',
#  'HIGD1AP1',
#  'HLA-A',
#  'HLA-DMA',
#  'HLA-DMB',
#  'HLA-DPB1',
#  'HLA-DPB2',
#  'HLA-DQA1',
#  'HLA-DQB1',
#  'HLA-DQB1-AS1',
#  'HLA-DQB3',
#  'HLA-DRA',
#  'HLA-DRB1',
#  'HLA-DRB5',
#  'HLA-DRB9',
#  'HLA-K',
#  'HLA-S',
#  'HLA-U',
#  'HLA-W',
#  'HMGA1',
#  'HNF1A',
#  'HNF1B',
#  'HNF4A',
#  'HNRNPA1P41',
#  'HORMAD2',
#  'HPSE2',
#  'HS3ST2',
#  'HSPD1',
#  'IAPP',
#  'IATPR',
#  'ICA1',
#  'ICOS',
#  'IFIH1',
#  'IFNG',
#  'IGF1',
#  'IGF2',
#  'IGF2-AS',
#  'IGF2BP2',
#  'IGFBP1',
#  'IGFBP2',
#  'IGFBP3',
#  'IKZF1',
#  'IKZF3',
#  'IKZF4',
#  'IL10',
#  'IL12B',
#  'IL15',
#  'IL17A',
#  'IL18',
#  'IL18RAP',
#  'IL1B',
#  'IL1R1',
#  'IL1RN',
#  'IL2',
#  'IL21',
#  'IL21-AS1',
#  'IL23R',
#  'IL25',
#  'IL27',
#  'IL2RA',
#  'IL2RA::GH10J006049',
#  'IL2RB',
#  'IL4',
#  'IL6',
#  'IL6-AS1',
#  'IL6R',
#  'IL7R',
#  'INPP5B',
#  'INS',
#  'INS-IGF2',
#  'INSR',
#  'IRF1',
#  'IRF1-AS1',
#  'IRF4',
#  'IRS1',
#  'IRS2',
#  'ITGB7',
#  'ITGB8',
#  'ITPR3',
#  'ITSN2',
#  'JAK2',
#  'JAZF1',
#  'JAZF1-AS1',
#  'KCNJ11',
#  'KCNQ1',
#  'KCNQ1DN',
#  'KEAP1',
#  'KIAA1109',
#  'KIF17',
#  'KLF3-AS1',
#  'KLRG1',
#  'LEP',
#  'LEPR',
#  'LIF-AS1',
#  'LINC00243',
#  'LINC00320',
#  'LINC00460',
#  'LINC00892',
#  'LINC00993',
#  'LINC01104',
#  'LINC01149',
#  'LINC01179',
#  'LINC01250',
#  'LINC01550',
#  'LINC01845',
#  'LINC01882',
#  'LINC02009',
#  'LINC02225',
#  'LINC02341',
#  'LINC02357',
#  'LINC02362',
#  'LINC02390',
#  'LINC02516',
#  'LINC02539',
#  'LINC02649',
#  'LINC02694',
#  'LINC02757',
#  'LINC02771',
#  'LINC02773',
#  'LIPC',
#  'LMO7',
#  'LPAR3',
#  'LRP1B',
#  'LRP5',
#  'LRRK2',
#  'LURAP1L',
#  'LURAP1L-AS1',
#  'M6PR',
#  'MADCAM1',
#  'MAGI3',
#  'MAGOH3P',
#  'MAPK8IP1',
#  'MAPT',
#  'MEG3',
#  'MHENCR',
#  'MICA',
#  'MIR130B',
#  'MIR21',
#  'MIR210',
#  'MIR3681HG',
#  'MIR3939',
#  'MIR4425',
#  'MIR4432HG',
#  'MIR4686',
#  'MIR588',
#  'MNDA',
#  'MTCO3P1',
#  'MTNR1B',
#  'NAA25',
#  'NCOA1',
#  'NCR3',
#  'NDUFA4',
#  'NDUFA5',
#  'NDUFB8',
#  'NDUFC2',
#  'NDUFS3',
#  'NEMF',
#  'NEUROD1',
#  'NFIB',
#  'NKD1',
#  'NKX2-3',
#  'NOL8P1',
#  'NOS2',
#  'NOTCH2',
#  'NOTCH4',
#  'NPIPB6',
#  'NPPA',
#  'NR4A3',
#  'NRP1',
#  'NUPR1',
#  'OAS1',
#  'OR10AA1P',
#  'OR2P1P',
#  'OR2W1',
#  'OR7E158P',
#  'ORMDL3',
#  'PAX4',
#  'PDCD1',
#  'PDE4A',
#  'PDX1',
#  'PFKFB3',
#  'PGM1',
#  'PHF20L1',
#  'PHLDB2',
#  'PHTF1',
#  'PI4KA',
#  'PLAGL1',
#  'PLB1',
#  'PLEKHA1',
#  'PLGRKT',
#  'PNPO',
#  'PON1',
#  'POU5F1',
#  'PPARG',
#  'PPIL2',
#  'PPP1R3A',
#  'PRF1',
#  'PRKCQ',
#  'PRKD2',
#  'PRR15L',
#  'PSD3',
#  'PSMB2',
#  'PSMB8',
#  'PTGES',
#  'PTPN1',
#  'PTPN2',
#  'PTPN22',
#  'PTPN3',
#  'PTPRC',
#  'PTPRN',
#  'PVT1',
#  'PXK',
#  'QRFPR',
#  'RAB5B',
#  'RAC2',
#  'RAD51B',
#  'RASGPR1',
#  'RASGRP1',
#  'RBFOX1',
#  'RBM17',
#  'RBP4',
#  'RDM1P3',
#  'REN',
#  'RETN',
#  'RGMA',
#  'RGS1',
#  'RMI2',
#  'RN7SKP113',
#  'RN7SL366P',
#  'RNA5SP94',
#  'RNASET2',
#  'RNLS',
#  'RNU1-150P',
#  'RNU6-1133P',
#  'RNU6-12P',
#  'RNU6-144P',
#  'RNU6-320P',
#  'RNU6-474P',
#  'RPAP2',
#  'RPL22P23',
#  'RPL23AP12',
#  'RPL32P23',
#  'RPL35P9',
#  'RPL3P2',
#  'RPP21',
#  'RPS23P10',
#  'RPS26',
#  'RPS6KA4',
#  'RSBN1',
#  'RUNX3',
#  'SBK1',
#  'SEPHS1P2',
#  'SEPTIN2',
#  'SFTA2',
#  'SH2B3',
#  'SIRPG',
#  'SIRPG-AS1',
#  'SKAP2',
#  'SLC15A3',
#  'SLC1A2',
#  'SLC25A28',
#  'SLC25A38P1',
#  'SLC29A3',
#  'SLC2A2',
#  'SLC2A4',
#  'SLC30A10',
#  'SLC30A8',
#  'SLC4A10',
#  'SLC5A2',
#  'SLC9A4',
#  'SMAD3',
#  'SMARCE1',
#  'SND1',
#  'SOCS1',
#  'SOCS3',
#  'SOD2',
#  'SPRYD3',
#  'SRRM1P3',
#  'SST',
#  'STAT4',
#  'STK39',
#  'STMN3',
#  'STMND1',
#  'STX17-AS1',
#  'STYX',
#  'SUMO4',
#  'SUOX',
#  'TACC3',
#  'TAGAP-AS1',
#  'TAP1',
#  'TAP2',
#  'TATDN3',
#  'TBC1D4',
#  'TCF7L2',
#  'TENM3',
#  'TG',
#  'TH',
#  'THADA',
#  'TLL1',
#  'TLR4',
#  'TLR7/8',
#  'TM9SF2',
#  'TNF',
#  'TNFAIP3',
#  'TNFRSF11B',
#  'TNFRSF25',
#  'TNFSF15',
#  'TOX',
#  'TPO',
#  'TRIM31',
#  'TRIM31-AS1',
#  'TRIM39-RPP21',
#  'TSBP1',
#  'TSBP1-AS1',
#  'TTC33',
#  'TTC34',
#  'TUBB4BP5',
#  'TYK2',
#  'UBASH3A',
#  'UMOD',
#  'UQCRHP1',
#  'USP31',
#  'VDR',
#  'VEGFA',
#  'WFS1',
#  'Y_RNA',
#  'ZDHHC17',
#  'ZFP1',
#  'ZFP36L1',
#  'ZFP57',
#  'ZMIZ1',
#  'ZPBP2'}

# %%
single_reps_genes = set(single_reps.genename.values.tolist())

# %%
highly_studied_genes = single_reps_genes.intersection(consensus_genes)

# %%
highly_studied_genes
# Out:
# {'BACH2', 'TYK2'}

# %%
understudied_genes = single_reps_genes.difference(consensus_genes)

# %%
understudied_genes
# Out:
# {'AC008755.1',
#  'AIF1',
#  'BTN2A1',
#  'BTN3A2',
#  'CLEC2B',
#  'CLEC7A',
#  'DCAF5',
#  'FLOT1',
#  'FYB1',
#  'LST1',
#  'LY6G5B',
#  'MAPKAPK5',
#  'PTGER4',
#  'RICTOR',
#  'RPL37',
#  'SAE1',
#  'SEH1L',
#  'SGF29',
#  'TRIM27',
#  'ZKSCAN4'}

# %% [markdown]
# #### Investigating lesser studied genes

# %%
understudied_sgl_genes = single_reps.loc[single_reps.genename.isin(understudied_genes)]

# %%
understudied_sgl_genes_fn = os.path.join(outdir, 'understudied_sgl_genes.tsv')
understudied_sgl_genes.to_csv(understudied_sgl_genes_fn, sep='\t')

# %%
understudied_sgl_genes_fn
# Out:
# 'results/main/compiled_sgl_approaches//understudied_sgl_genes.tsv'
